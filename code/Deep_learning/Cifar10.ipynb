# %% [markdown]
# ## Convolutional Neural Networks for CIFAR-10 multiclass image classification
# In this study, we compare different optimizers and investigate Cyclical Learning Rate scheduling method for classification of images in CIFAR-10 dataset. LR (Learning Rate) range test is employed to estimate the upper and lower bounds of learning rate scheduling. We also explore deeper architectures to increase classification accuracy. Image augmentation, Batch Normalization and Dropout methods are implemented to reduce overfitting observed with deeper neural networks.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from torchvision import datasets
from torchvision import transforms
import torchvision.models as models
from torch.utils.data.sampler import SubsetRandomSampler
from torch.nn.utils import clip_grad_norm_, clip_grad_value_
from torch.nn.init import xavier_uniform_
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
#define functions to split train set into train and validation sets and generate train, validation & test dataloaders
def get_train_valid_loader(batch_size,
                           augment,
                           data_dir = './data',
                           random_seed=42,
                           valid_size=0.2,
                           shuffle=True,
                           show_sample=False,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. 

    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.

    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms
    valid_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
    ])
    if augment:
        train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = data_iter.next()
        X = images.numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)


def get_test_loader(data_dir,
                    batch_size,
                    shuffle=True,
                    num_workers=4,
                    pin_memory=False):
    """
    Utility function for loading and returning a multi-process
    test iterator over the CIFAR-10 dataset.

    If using CUDA, num_workers should be set to 1 and pin_memory to True.

    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - shuffle: whether to shuffle the dataset after every epoch.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.

    Returns
    -------
    - data_loader: test set iterator.
    """
    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    )

    # define transform
    transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    dataset = datasets.CIFAR10(
        root=data_dir, train=False,
        download=True, transform=transform,
    )

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    return data_loader

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#define function to calculate accuracy by comparing predictions obtained by feed forward method and labels
def get_accuracy(output, labels):
    """
    Return the accuracy of the model on the input data and actual ground truth.
    """
    
    _,predicted = torch.max(output.data,1)
    total = labels.size(0)
    correct = (predicted == labels).sum()
    accuracy = torch.true_divide(100*correct, total)
    return accuracy

# %%
#define function to plot loss and accuracy curves for train and validation sets
def plot_curves(train_accuracies,train_losses,validation_accuracies,validation_losses, ax=None):
    
    plt.figure(figsize=(8,6))
    if ax is None:
        ax=plt.gca()
        
    # Plot the results (shifting validation curves appropriately)
    color = 'tab:red'
    ax.set_xlabel('Number of epochs', fontsize=12)
    ax.set_ylabel('Accuracy', color=color, fontsize=12)
    n = len(train_accuracies)
    ax.plot(np.arange(0,n),train_accuracies, color='orange', label='Train accuracy')
    ax.plot(np.arange(0,n),validation_accuracies,'r', label='Val accuracy')
    ax.tick_params(axis='y', labelcolor=color)
    ax.set_ylim(0,105)
    ax.legend(frameon=False)
    ax.grid(True)
    ax2 = ax.twinx()
    color = 'tab:blue'
    ax2.set_ylabel('loss', color=color, fontsize=12)
    ax2.plot(np.arange(0,n),train_losses,'b', label='Train loss')
    ax2.plot(np.arange(0,n),validation_losses,'g', label='Val loss')
    ax2.legend(frameon=False, loc='upper center')
    ax2.set_ylim(0,2.5)
    return ax

# %%
#create train and validation dataloaders
trainloader,validloader = get_train_valid_loader(batch_size=50,
                           augment=False,
                           data_dir = './data',
                           random_seed=42,
                           valid_size=0.2,
                           shuffle=True,
                           show_sample=False,
                           num_workers=4,
                           pin_memory=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataloaders = {'train':trainloader, 'validation': validloader}

# %%
#create test dataloader
testloader = get_test_loader(data_dir = './data',
                    batch_size=50,
                    shuffle=True,
                    num_workers=4,
                    pin_memory=False)
# Out:
# Files already downloaded and verified

# %%
#create class for CNN1 network architecture
class Model1(nn.Module):
    def __init__(self):
        super(Model1, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 6, kernel_size=5),
            #nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.MaxPool2d(2))
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(6, 16, kernel_size=5),
            #nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
          
        
        self.fc_layers = nn.Sequential(
            nn.Linear(400,120),
            #nn.Dropout(0.1),
            nn.Linear(120,84),
            #nn.Dropout(0.1),
            nn.Linear(84,10)
        )
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc_layers(out)
        return out

# %%
#loss function
criterion = nn.CrossEntropyLoss()

# %%
#define function to train model on train set and evaluate on validation set. 
def train_model(model, optimizer_key, n_epochs, plot_history=True,print_stats=True):
    """Trains model on train set and evaluates on validation set.
    Params:
    1. model - CNN architecture
    2. optimizer_key: optimizer
    3.n_epochs: number of epochs
    4.plot_history: if true, plots loss and accuracy curves for train and validation sets
    print_stats: of true, prints average loss and accuracy for train and validation sets after every 100 minibatches
    
    Returns:
    list of average train and validation accuracies after every epoch

"""
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    model = model.to(device)
    if optimizer_key == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=0.01)
    elif optimizer_key == 'Adam':
        optimizer = optim.Adam(model.parameters())    
    elif optimizer_key == 'Adagrad':
        optimizer = optim.Adagrad(model.parameters())
    elif optimizer_key == 'Adamax':
        optimizer = optim.Adamax(model.parameters())
    elif optimizer_key == 'Adadelta':
        optimizer = optim.Adadelta(model.parameters())
        
        
    for epoch in range(n_epochs):
        

        # Each epoch has a training and validation phase
        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            running_loss = 0.0
            running_accuracy = 0.0
            epoch_loss = 0.0
            epoch_accuracy = 0.0
        
            # Iterate over data.
            for i, (inputs,labels) in enumerate(dataloaders[phase]):

            
                # forward pass to get outputs
                output = model(inputs)

                # calculate the loss between predicted and target keypoints
                loss = criterion(output, labels)
                
                
                # zero the parameter (weight) gradients
                optimizer.zero_grad()

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    # update the weights
                    optimizer.step()
                
                accuracy = get_accuracy(output,labels)    
                running_loss += loss.item()
                epoch_loss += loss.item()
                running_accuracy += accuracy.item()
                epoch_accuracy += accuracy.item()
            
                
                if print_stats:
                    if i % 100 == 99:    # print every 100 mini-batches
                        print('[%d, %5d] %s loss: %.3f' %(epoch + 1, i + 1, phase,running_loss / 100),
                             ', accuracy: %.1f' %(running_accuracy / 100) +'%')
                        running_loss = 0.0
                        running_accuracy = 0.0
                
                
            if phase == 'train':
                train_losses.append(epoch_loss/len(dataloaders[phase]))
                train_accuracies.append(epoch_accuracy/len(dataloaders[phase]))
            else:
                validation_losses.append(epoch_loss/len(dataloaders[phase]))
                validation_accuracies.append(epoch_accuracy/len(dataloaders[phase]))
                
    # plot curves
    if plot_history:
        plot_curves(train_accuracies,train_losses,validation_accuracies,validation_losses, ax=None)
    return train_accuracies,validation_accuracies

# %%
#train model using CNN1, with default learning rate for each optimizer for 25 epochs 
default_performances = []
for key in ["SGD","Adam","Adagrad","Adamax","Adadelta"]:
    print('testing {}:' .format(key))
    performance = train_model(model=Model1(), optimizer_key=key, n_epochs=25, plot_history=False,print_stats=False)
    default_performances.append(performance)
# Out:
# testing SGD:
# testing Adam:
# testing Adagrad:
# testing Adamax:
# testing Adadelta:

# %%
#compare accuracies of optimizers at default learning rate
optimizers_list = ['SGD','Adam','Adagrad','Adamax','Adadelta']
plt.figure(figsize=(8,6))
for i in range(len(default_performances)):
    n = len(default_performances[i][0])
    plt.plot(np.arange(0,n),default_performances[i][0], label = optimizers_list[i])
    plt.xlabel('Number of epochs', fontsize=14)
    plt.ylabel('Train Accuracy',fontsize=14)
    plt.ylim(20,80)
    plt.legend(fontsize=14)
    plt.title('Optimizers at default learning rates', fontsize=18)

# %%
#define function to conduct LR range test

def lr_range_finder(model,optimizer_key,start_lr,end_lr, lr_find_epochs, ax=None):
    """Create lr-loss plot to determine upper bound of cyclical learning rate schedule using LR range test.
    params
    1. model: CNN architecture to use for running the test
    2. optimizer_key: optimizer
    3. start_lr: base learning rate
    4. end_lr: maximim learning rate
    5. lr_find_epochs: number of epochs 
    6. ax: if specified, plot lr-loss curve on the axes, else create new figure
    """
    model = model.to(device)
    if optimizer_key == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=start_lr)
    elif optimizer_key == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=start_lr)    
    elif optimizer_key == 'Adagrad':
        optimizer = optim.Adagrad(model.parameters(), lr=start_lr)
    elif optimizer_key == 'Adamax':
        optimizer = optim.Adamax(model.parameters(), lr=start_lr)
    elif optimizer_key == 'Adadelta':
        optimizer = optim.Adadelta(model.parameters(), lr=start_lr)


    #LR function lambda
    lr_lambda = lambda x: math.exp(x * math.log(end_lr / start_lr) / (lr_find_epochs * len( dataloaders["train"])))
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
    # Run the experiment 

    lr_find_loss = []
    lr_find_lr = []

    iter = 0

    smoothing = 0.05

    for i in range(lr_find_epochs):
        
        for inputs, labels in dataloaders["train"]:
    
            # Send to device
            inputs = inputs.to(device)
            labels = labels.to(device)
    
            # Training mode and zero gradients
            model.train()
            optimizer.zero_grad()
    
            # Get outputs to calc loss
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward pass
            loss.backward()
            optimizer.step()

            # Update LR
            scheduler.step()
            lr_step = optimizer.state_dict()["param_groups"][0]["lr"]
            lr_find_lr.append(lr_step)

            # smooth the loss
            if iter==0:
                lr_find_loss.append(loss)
            else:
                loss = smoothing  * loss + (1 - smoothing) * lr_find_loss[-1]
                lr_find_loss.append(loss)
     
        iter += 1
        
        lr = np.asarray(lr_find_lr)
        losses = np.asarray(lr_find_loss).astype('float')
        
        plt.figure(figsize=(8,6))
        if ax is None:
            ax=plt.gca()
            
        ax.plot(lr,losses)
        ax.set_xscale('log')
        ax.set_xlabel('Learning rate (log)', fontsize = 14)
        ax.set_ylabel('loss', fontsize=14)
        ax.minorticks_on()
        ax.tick_params(which='major', length=10, width=2, direction='inout', labelsize=14)
        ax.tick_params(which='minor', length=5, width=2, direction='in', labelsize=14)
        ax.grid(which='both')

# %%
#conduct lr-range test using CNN1 for each optimizer and plot lr-loss curves
fig,axes = plt.subplots(3,2, figsize = (16,22))
fig.suptitle('Learning rate (LR) - range tests for optimizers', fontsize = 18)
axes[2,1].axis('off')
lr_range_finder(Model1(),'SGD',start_lr=1e-7,end_lr=0.2, lr_find_epochs=2, ax=axes[0,0])
axes[0,0].set_title('SGD')
axes[0,0].axvline(x=5e-2)
lr_range_finder(Model1(),'Adam',start_lr=1e-7,end_lr=1e-2, lr_find_epochs=2, ax=axes[0,1])
axes[0,1].set_title('Adam')
axes[0,1].axvline(x=1e-3)
lr_range_finder(Model1(),'Adagrad',start_lr=1e-7,end_lr=1e-1, lr_find_epochs=2, ax=axes[1,0])
axes[1,0].set_title('Adagrad')
axes[1,0].axvline(x=1e-2)
lr_range_finder(Model1(),'Adamax',start_lr=1e-7,end_lr=1e-1, lr_find_epochs=2, ax=axes[1,1])
axes[1,1].set_title('Adamax')
axes[1,1].axvline(x=2e-3)
lr_range_finder(Model1(),'Adadelta',start_lr=1e-7,end_lr=1.2, lr_find_epochs=2, ax=axes[2,0])
axes[2,0].set_title('Adadelta')
axes[2,0].axvline(x=1e-1)
plt.tight_layout();

# %%
#define function to create cyclical learning rate bsed scheduler
def cyclical_lr(stepsize, min_lr=2e-3, max_lr=2e-2):

    # Scaler: we can adapt this if we do not want the triangular CLR
    scaler = lambda x: 1.

    # Lambda function to calculate the LR
    lr_lambda = lambda it: min_lr + (max_lr - min_lr) * relative(it, stepsize)

    # Additional function to see where on the cycle we are
    def relative(it, stepsize):
        cycle = math.floor(1 + it / (2 * stepsize))
        x = abs(it / stepsize - 2 * cycle + 1)
        return max(0, (1 - x)) * scaler(cycle)

    return lr_lambda

# %%
#define function to train model on train set with cyclic learning rate scheduling method, evaluate on validation model
def train_model_lrs(model, optimizer_key, n_epochs,lr_max,path, plot_history=True,print_stats=True):
    """
    Train model on train set with cyclic learning rate scheduling method, evaluate on validation model.
    
    Params:
    1. model - CNN architecture
    2. optimizer_key: optimizer
    3.n_epochs: number of epochs
    4.lr_max: upper bound determined using lr-range test
    5.path: path to save parameters of trained model
    6.plot_history: if true, plots loss and accuracy curves for train and validation sets
    7. print_stats: of true, prints average loss and accuracy for train and validation sets after every 100 minibatches
    
    Returns:
    lists of average train and validation accuracies after every epoch


    """
    
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    
    model = model.to(device)
    if optimizer_key == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=1.)
    elif optimizer_key == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=1.)    
    elif optimizer_key == 'Adagrad':
        optimizer = optim.Adagrad(model.parameters(), lr=1.)
    elif optimizer_key == 'Adamax':
        optimizer = optim.Adamax(model.parameters(), lr=1.)
    elif optimizer_key == 'Adadelta':
        optimizer = optim.Adadelta(model.parameters(), lr=1.)
        
    factor = 6
    end_lr = lr_max
    step_size = 4*len(trainloader)
    clr = cyclical_lr(step_size, min_lr=end_lr/factor, max_lr=end_lr)
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, [clr])


    
    for epoch in range(n_epochs):
        

        # Each epoch has a training and validation phase
        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            running_loss = 0.0
            running_accuracy = 0.0
            epoch_loss = 0.0
            epoch_accuracy = 0.0
        
            # Iterate over data.
            for i, (inputs,labels) in enumerate(dataloaders[phase]):

            
                # forward pass to get outputs
                output = model(inputs)

                # calculate the loss between predicted and target keypoints
                loss = criterion(output, labels)
                
                
                # zero the parameter (weight) gradients
                optimizer.zero_grad()

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    
                    # Clip the gradients norm to avoid them becoming too large
                    clip_grad_norm_(model.parameters(), 5)
                    
                    # update the weights
                    optimizer.step()
                    
                    # Update the LR
                    scheduler.step()
                    lr_sched_test = scheduler.get_last_lr()
                
                accuracy = get_accuracy(output,labels)    
                running_loss += loss.item()
                epoch_loss += loss.item()
                running_accuracy += accuracy.item()
                epoch_accuracy += accuracy.item()
            
                
                if print_stats:
                    if i % 100 == 99:    # print every 100 mini-batches
                        print('[%d, %5d] %s loss: %.3f' %(epoch + 1, i + 1, phase,running_loss / 100),
                             ', accuracy: %.1f' %(running_accuracy / 100) +'%')
                        running_loss = 0.0
                        running_accuracy = 0.0
                
                
            if phase == 'train':
                train_losses.append(epoch_loss/len(dataloaders[phase]))
                train_accuracies.append(epoch_accuracy/len(dataloaders[phase]))
            else:
                validation_losses.append(epoch_loss/len(dataloaders[phase]))
                validation_accuracies.append(epoch_accuracy/len(dataloaders[phase]))
                
    # plot curves
    if plot_history:
        plot_curves(train_accuracies,train_losses,validation_accuracies,validation_losses, ax=None)
    
    
    torch.save(model.state_dict(), path)

    
    return train_accuracies,validation_accuracies

# %%
#Train model using CNN1, SGD optimizer with CLR method, for 25 epochs
sgd_lrs = train_model_lrs(Model1(), 'SGD', n_epochs=25,lr_max=5e-2, plot_history=True,print_stats=False)

# %%
#Train model using CNN1, Adam optimizer with CLR method, for 25 epochs
adam_lrs = train_model_lrs(Model1(), 'Adam', n_epochs=25,lr_max=1e-3, plot_history=True,print_stats=False)

# %%
#Train model using CNN1, Adagrad optimizer with CLR method, for 25 epochs
adagrad_lrs = train_model_lrs(Model1(), 'Adagrad', n_epochs=25,lr_max=1e-2, plot_history=True,print_stats=False)

# %%
##Train model using CNN1, Adamax optimizer with CLR method, for 25 epochs
adamax_lrs = train_model_lrs(Model1(), 'Adamax', n_epochs=25,lr_max=2e-3, plot_history=True,print_stats=False)

# %%
#Train model using CNN1, Adadelta optimizer with CLR method, for 25 epochs
adadelta_lrs = train_model_lrs(Model1(), 'Adadelta', n_epochs=25,lr_max=1e-1, plot_history=True,print_stats=False)

# %%
#compare accuracies of optimizers with cyclic learning rates
optimizers_names = ['SGD','Adam','Adagrad','Adamax','Adadelta']
plt.figure(figsize=(8,6))
for i in range(len(lrs_performances)):
    n = len(lrs_performances[i])
    plt.plot(np.arange(0,n),lrs_performances[i], label = optimizers_names[i])
    plt.xlabel('Number of epochs', fontsize=14)
    plt.ylabel('Train Accuracy',fontsize=14)
    plt.ylim(20,80)
    plt.legend(fontsize=14)
    plt.title('Optimizers with cyclic learning rate scheduling', fontsize=18)

# %%
#compare generalization gap with Adam, Adamax and SGD optimizers run with CNN1, CLR method
fig,(ax1,ax2,ax3) = plt.subplots(1,3, figsize = (16,4))
n = len(adamax_lrs[0])
ax1.plot(np.arange(0,n),adamax_lrs[0], label = 'Train', color = 'orange')
ax1.plot(np.arange(0,n), adamax_lrs[1], label = 'Validation', color = 'r')
ax1.set_ylim(30,70)
ax1.set_title('CNN1 - Adamax optimizer',fontsize=15)
ax1.set_ylabel('Train accuracy', fontsize = 12)
ax1.set_xlabel('Number of epochs', fontsize=12)
ax1.legend()
ax2.plot(np.arange(0,n),adam_lrs[0], label = 'Train', color = 'orange')
ax2.plot(np.arange(0,n), adam_lrs[1], label = 'Validation', color = 'r')
ax2.set_ylim(30,70)
ax2.set_xlabel('Number of epochs',fontsize=12)
ax2.set_title('CNN1 - Adam optimizer',fontsize=15)
ax2.legend()
ax3.plot(np.arange(0,n),sgd_lrs[0], label = 'Train', color = 'orange')
ax3.plot(np.arange(0,n), sgd_lrs[1], label = 'Validation', color = 'r')
ax3.set_ylim(30,70)
ax3.set_title('CNN1 - SGD optimizer',fontsize=15)
ax3.set_xlabel('Number of epochs',fontsize=12)
ax3.legend()

# %%
optimizers_list = [sgd_lrs,adam_lrs,adagrad_lrs,adamax_lrs,adadelta_lrs]
lrs_performances = [x[0] for x in optimizers_list]

# %%
#comparisong SGD optimizer with default learning rate and CLR method scheduling
plt.figure(figsize=(8,6))
n = len(adamax_lrs[0])
plt.plot(np.arange(0,n),default_performances[0][0], label = 'learning rate: 0.01')
plt.plot(np.arange(0,n),sgd_lrs[0], label = 'Cyclic learning rate')
plt.xlabel('Number of epochs', fontsize=14)
plt.ylabel('Train Accuracy',fontsize=14)
plt.ylim(0,100)
plt.legend()
plt.title('Comparison of learning rates: SGD', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Comparison of learning rates: SGD')

# %%
#define class for CNN2 architecture
class Model2(nn.Module):
    def __init__(self):
        super(Model2, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=3),
            #nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.MaxPool2d(2))
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 32, kernel_size=3),
            #nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
          
        
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3),
            #nn.BatchNorm2d(64),
            nn.ReLU())
        
        self.fc_layers = nn.Sequential(
            nn.Linear(1024,120),
            #nn.Dropout(0.1),
            nn.Linear(120,84),
            #nn.Dropout(0.1),
            nn.Linear(84,10)
        )
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)
        out = self.fc_layers(out)
        return out

# %%
#LR range test for adamax optimizer with Model2
lr_range_finder(Model2(),'Adamax',start_lr=1e-7,end_lr=1e-1, lr_find_epochs=2, ax=None)

# %%
#run CNN2 with Adamax optimizer, CLR method scheduling for 25 epochs
adamax_lrs_2 = train_model_lrs(Model2(), 'Adamax', n_epochs=25,lr_max=2e-3, plot_history=True,print_stats=True)
# Out:
# [1,   100] train loss: 2.199 , accuracy: 19.9%
# [1,   200] train loss: 1.947 , accuracy: 28.6%
# [1,   300] train loss: 1.842 , accuracy: 33.1%
# [1,   400] train loss: 1.776 , accuracy: 35.2%
# [1,   500] train loss: 1.739 , accuracy: 37.6%
# [1,   600] train loss: 1.680 , accuracy: 38.8%
# [1,   700] train loss: 1.641 , accuracy: 40.6%
# [1,   800] train loss: 1.620 , accuracy: 41.5%
# [1,   100] validation loss: 1.580 , accuracy: 41.8%
# [1,   200] validation loss: 1.588 , accuracy: 42.4%
# [2,   100] train loss: 1.562 , accuracy: 42.9%
# [2,   200] train loss: 1.513 , accuracy: 43.8%
# [2,   300] train loss: 1.506 , accuracy: 45.6%
# [2,   400] train loss: 1.486 , accuracy: 45.9%
# [2,   500] train loss: 1.451 , accuracy: 47.0%
# [2,   600] train loss: 1.458 , accuracy: 46.7%
# [2,   700] train loss: 1.432 , accuracy: 48.4%
# [2,   800] train loss: 1.426 , accuracy: 49.0%
# [2,   100] validation loss: 1.377 , accuracy: 50.8%
# [2,   200] validation loss: 1.412 , accuracy: 50.1%
# [3,   100] train loss: 1.396 , accuracy: 50.4%
# [3,   200] train loss: 1.355 , accuracy: 51.0%
# [3,   300] train loss: 1.354 , accuracy: 51.8%
# [3,   400] train loss: 1.336 , accuracy: 51.2%
# [3,   500] train loss: 1.313 , accuracy: 52.7%
# [3,   600] train loss: 1.299 , accuracy: 54.0%
# [3,   700] train loss: 1.293 , accuracy: 53.7%
# [3,   800] train loss: 1.259 , accuracy: 54.9%
# [3,   100] validation loss: 1.249 , accuracy: 55.6%
# [3,   200] validation loss: 1.271 , accuracy: 54.1%
# [4,   100] train loss: 1.226 , accuracy: 55.8%
# [4,   200] train loss: 1.204 , accuracy: 56.6%
# [4,   300] train loss: 1.207 , accuracy: 57.7%
# [4,   400] train loss: 1.198 , accuracy: 58.3%
# [4,   500] train loss: 1.175 , accuracy: 57.8%
# [4,   600] train loss: 1.147 , accuracy: 59.7%
# [4,   700] train loss: 1.158 , accuracy: 59.1%
# [4,   800] train loss: 1.183 , accuracy: 58.1%
# [4,   100] validation loss: 1.131 , accuracy: 60.2%
# [4,   200] validation loss: 1.138 , accuracy: 59.4%
# [5,   100] train loss: 1.077 , accuracy: 61.9%
# [5,   200] train loss: 1.105 , accuracy: 61.5%
# [5,   300] train loss: 1.078 , accuracy: 61.3%
# [5,   400] train loss: 1.073 , accuracy: 61.7%
# [5,   500] train loss: 1.080 , accuracy: 62.1%
# [5,   600] train loss: 1.059 , accuracy: 62.5%
# [5,   700] train loss: 1.007 , accuracy: 64.3%
# [5,   800] train loss: 1.054 , accuracy: 62.9%
# [5,   100] validation loss: 1.050 , accuracy: 63.9%
# [5,   200] validation loss: 1.092 , accuracy: 61.7%
# [6,   100] train loss: 0.968 , accuracy: 65.3%
# [6,   200] train loss: 0.979 , accuracy: 65.4%
# [6,   300] train loss: 0.974 , accuracy: 66.0%
# [6,   400] train loss: 0.980 , accuracy: 65.2%
# [6,   500] train loss: 0.951 , accuracy: 67.2%
# [6,   600] train loss: 0.966 , accuracy: 66.3%
# [6,   700] train loss: 0.974 , accuracy: 65.5%
# [6,   800] train loss: 0.935 , accuracy: 68.5%
# [6,   100] validation loss: 0.973 , accuracy: 66.9%
# [6,   200] validation loss: 1.013 , accuracy: 65.3%
# [7,   100] train loss: 0.890 , accuracy: 68.3%
# [7,   200] train loss: 0.899 , accuracy: 68.8%
# [7,   300] train loss: 0.892 , accuracy: 69.2%
# [7,   400] train loss: 0.900 , accuracy: 69.0%
# [7,   500] train loss: 0.879 , accuracy: 69.0%
# [7,   600] train loss: 0.892 , accuracy: 68.7%
# [7,   700] train loss: 0.878 , accuracy: 69.5%
# [7,   800] train loss: 0.863 , accuracy: 70.4%
# [7,   100] validation loss: 0.965 , accuracy: 66.4%
# [7,   200] validation loss: 0.965 , accuracy: 66.9%
# [8,   100] train loss: 0.849 , accuracy: 70.8%
# [8,   200] train loss: 0.829 , accuracy: 71.0%
# [8,   300] train loss: 0.829 , accuracy: 71.2%
# [8,   400] train loss: 0.809 , accuracy: 71.9%
# [8,   500] train loss: 0.810 , accuracy: 72.1%
# [8,   600] train loss: 0.816 , accuracy: 72.0%
# [8,   700] train loss: 0.800 , accuracy: 71.9%
# [8,   800] train loss: 0.809 , accuracy: 71.2%
# [8,   100] validation loss: 0.958 , accuracy: 67.4%
# [8,   200] validation loss: 0.944 , accuracy: 68.0%
# [9,   100] train loss: 0.792 , accuracy: 72.9%
# [9,   200] train loss: 0.757 , accuracy: 74.5%
# [9,   300] train loss: 0.794 , accuracy: 72.6%
# [9,   400] train loss: 0.801 , accuracy: 72.5%
# [9,   500] train loss: 0.815 , accuracy: 71.9%
# [9,   600] train loss: 0.800 , accuracy: 72.5%
# [9,   700] train loss: 0.785 , accuracy: 72.5%
# [9,   800] train loss: 0.815 , accuracy: 71.4%
# [9,   100] validation loss: 0.969 , accuracy: 66.5%
# [9,   200] validation loss: 0.958 , accuracy: 67.1%
# [10,   100] train loss: 0.788 , accuracy: 72.4%
# [10,   200] train loss: 0.767 , accuracy: 73.3%
# [10,   300] train loss: 0.790 , accuracy: 72.6%
# [10,   400] train loss: 0.801 , accuracy: 71.8%
# [10,   500] train loss: 0.845 , accuracy: 70.6%
# [10,   600] train loss: 0.808 , accuracy: 71.4%
# [10,   700] train loss: 0.818 , accuracy: 70.8%
# [10,   800] train loss: 0.827 , accuracy: 71.7%
# [10,   100] validation loss: 0.970 , accuracy: 67.1%
# [10,   200] validation loss: 0.987 , accuracy: 66.8%
# [11,   100] train loss: 0.785 , accuracy: 72.9%
# [11,   200] train loss: 0.794 , accuracy: 72.0%
# [11,   300] train loss: 0.796 , accuracy: 71.5%
# [11,   400] train loss: 0.813 , accuracy: 71.0%
# [11,   500] train loss: 0.796 , accuracy: 72.2%
# [11,   600] train loss: 0.829 , accuracy: 70.8%
# [11,   700] train loss: 0.858 , accuracy: 70.0%
# [11,   800] train loss: 0.832 , accuracy: 71.5%
# [11,   100] validation loss: 0.978 , accuracy: 66.2%
# [11,   200] validation loss: 1.009 , accuracy: 65.3%
# [12,   100] train loss: 0.777 , accuracy: 72.4%
# [12,   200] train loss: 0.782 , accuracy: 73.1%
# [12,   300] train loss: 0.797 , accuracy: 72.4%
# [12,   400] train loss: 0.778 , accuracy: 73.4%
# [12,   500] train loss: 0.832 , accuracy: 70.7%
# [12,   600] train loss: 0.828 , accuracy: 70.9%
# [12,   700] train loss: 0.870 , accuracy: 68.4%
# [12,   800] train loss: 0.843 , accuracy: 71.0%
# [12,   100] validation loss: 1.018 , accuracy: 66.4%
# [12,   200] validation loss: 0.999 , accuracy: 66.5%
# [13,   100] train loss: 0.769 , accuracy: 73.7%
# [13,   200] train loss: 0.775 , accuracy: 72.2%
# [13,   300] train loss: 0.775 , accuracy: 73.0%
# [13,   400] train loss: 0.792 , accuracy: 71.9%
# [13,   500] train loss: 0.784 , accuracy: 72.6%
# [13,   600] train loss: 0.800 , accuracy: 72.3%
# [13,   700] train loss: 0.778 , accuracy: 72.8%
# [13,   800] train loss: 0.789 , accuracy: 72.1%
# [13,   100] validation loss: 1.016 , accuracy: 66.1%
# [13,   200] validation loss: 0.966 , accuracy: 67.5%
# [14,   100] train loss: 0.733 , accuracy: 74.2%
# [14,   200] train loss: 0.711 , accuracy: 74.8%
# [14,   300] train loss: 0.700 , accuracy: 76.0%
# [14,   400] train loss: 0.730 , accuracy: 74.5%
# [14,   500] train loss: 0.752 , accuracy: 73.2%
# [14,   600] train loss: 0.697 , accuracy: 75.7%
# [14,   700] train loss: 0.723 , accuracy: 74.4%
# [14,   800] train loss: 0.733 , accuracy: 74.4%
# [14,   100] validation loss: 0.963 , accuracy: 67.7%
# [14,   200] validation loss: 0.972 , accuracy: 67.8%
# [15,   100] train loss: 0.654 , accuracy: 77.4%
# [15,   200] train loss: 0.662 , accuracy: 76.9%
# [15,   300] train loss: 0.648 , accuracy: 77.1%
# [15,   400] train loss: 0.676 , accuracy: 76.0%
# [15,   500] train loss: 0.670 , accuracy: 77.0%
# [15,   600] train loss: 0.652 , accuracy: 76.5%
# [15,   700] train loss: 0.672 , accuracy: 77.0%
# [15,   800] train loss: 0.654 , accuracy: 77.1%
# [15,   100] validation loss: 0.964 , accuracy: 68.0%
# [15,   200] validation loss: 0.971 , accuracy: 68.1%
# [16,   100] train loss: 0.611 , accuracy: 78.9%
# [16,   200] train loss: 0.603 , accuracy: 78.7%
# [16,   300] train loss: 0.613 , accuracy: 78.9%
# [16,   400] train loss: 0.617 , accuracy: 78.3%
# [16,   500] train loss: 0.592 , accuracy: 79.4%
# [16,   600] train loss: 0.597 , accuracy: 79.0%
# [16,   700] train loss: 0.599 , accuracy: 79.6%
# [16,   800] train loss: 0.593 , accuracy: 79.4%
# [16,   100] validation loss: 0.988 , accuracy: 68.2%
# [16,   200] validation loss: 0.944 , accuracy: 69.7%
# [17,   100] train loss: 0.558 , accuracy: 80.2%
# [17,   200] train loss: 0.576 , accuracy: 80.1%
# [17,   300] train loss: 0.605 , accuracy: 79.0%
# [17,   400] train loss: 0.554 , accuracy: 80.7%
# [17,   500] train loss: 0.584 , accuracy: 79.8%
# [17,   600] train loss: 0.587 , accuracy: 79.2%
# [17,   700] train loss: 0.598 , accuracy: 79.4%
# [17,   800] train loss: 0.602 , accuracy: 78.8%
# [17,   100] validation loss: 1.001 , accuracy: 68.1%
# [17,   200] validation loss: 0.997 , accuracy: 69.2%
# [18,   100] train loss: 0.562 , accuracy: 80.3%
# [18,   200] train loss: 0.593 , accuracy: 79.1%
# [18,   300] train loss: 0.593 , accuracy: 79.2%
# [18,   400] train loss: 0.599 , accuracy: 78.4%
# [18,   500] train loss: 0.623 , accuracy: 78.6%
# [18,   600] train loss: 0.635 , accuracy: 78.0%
# [18,   700] train loss: 0.636 , accuracy: 77.5%
# [18,   800] train loss: 0.641 , accuracy: 77.5%
# [18,   100] validation loss: 1.021 , accuracy: 67.5%
# [18,   200] validation loss: 1.015 , accuracy: 67.9%
# [19,   100] train loss: 0.596 , accuracy: 79.9%
# [19,   200] train loss: 0.598 , accuracy: 79.0%
# [19,   300] train loss: 0.622 , accuracy: 78.2%
# [19,   400] train loss: 0.629 , accuracy: 77.9%
# [19,   500] train loss: 0.652 , accuracy: 77.2%
# [19,   600] train loss: 0.647 , accuracy: 77.2%
# [19,   700] train loss: 0.655 , accuracy: 76.6%
# [19,   800] train loss: 0.682 , accuracy: 76.1%
# [19,   100] validation loss: 1.009 , accuracy: 66.6%
# [19,   200] validation loss: 1.022 , accuracy: 67.3%
# [20,   100] train loss: 0.608 , accuracy: 78.8%
# [20,   200] train loss: 0.615 , accuracy: 77.7%
# [20,   300] train loss: 0.640 , accuracy: 77.4%
# [20,   400] train loss: 0.660 , accuracy: 76.1%
# [20,   500] train loss: 0.683 , accuracy: 76.4%
# [20,   600] train loss: 0.659 , accuracy: 76.9%
# [20,   700] train loss: 0.692 , accuracy: 75.6%
# [20,   800] train loss: 0.681 , accuracy: 75.9%
# [20,   100] validation loss: 1.019 , accuracy: 67.1%
# [20,   200] validation loss: 1.010 , accuracy: 67.5%
# [21,   100] train loss: 0.619 , accuracy: 78.3%
# [21,   200] train loss: 0.616 , accuracy: 78.7%
# [21,   300] train loss: 0.650 , accuracy: 77.0%
# [21,   400] train loss: 0.649 , accuracy: 76.9%
# [21,   500] train loss: 0.634 , accuracy: 77.5%
# [21,   600] train loss: 0.650 , accuracy: 76.8%
# [21,   700] train loss: 0.626 , accuracy: 78.0%
# [21,   800] train loss: 0.662 , accuracy: 77.2%
# [21,   100] validation loss: 1.030 , accuracy: 67.1%
# [21,   200] validation loss: 1.008 , accuracy: 67.5%
# [22,   100] train loss: 0.555 , accuracy: 80.3%
# [22,   200] train loss: 0.571 , accuracy: 79.8%
# [22,   300] train loss: 0.601 , accuracy: 78.7%
# [22,   400] train loss: 0.615 , accuracy: 77.5%
# [22,   500] train loss: 0.569 , accuracy: 79.6%
# [22,   600] train loss: 0.574 , accuracy: 79.9%
# [22,   700] train loss: 0.586 , accuracy: 78.9%
# [22,   800] train loss: 0.601 , accuracy: 79.5%
# [22,   100] validation loss: 1.045 , accuracy: 67.6%
# [22,   200] validation loss: 1.093 , accuracy: 66.3%
# [23,   100] train loss: 0.506 , accuracy: 82.5%
# [23,   200] train loss: 0.536 , accuracy: 81.1%
# [23,   300] train loss: 0.517 , accuracy: 81.8%
# [23,   400] train loss: 0.529 , accuracy: 80.6%
# [23,   500] train loss: 0.514 , accuracy: 81.2%
# [23,   600] train loss: 0.538 , accuracy: 81.0%
# [23,   700] train loss: 0.528 , accuracy: 81.2%
# [23,   800] train loss: 0.526 , accuracy: 81.8%
# [23,   100] validation loss: 1.080 , accuracy: 67.8%
# [23,   200] validation loss: 1.065 , accuracy: 68.2%
# [24,   100] train loss: 0.461 , accuracy: 83.8%
# [24,   200] train loss: 0.471 , accuracy: 83.4%
# [24,   300] train loss: 0.462 , accuracy: 83.8%
# [24,   400] train loss: 0.471 , accuracy: 83.6%
# [24,   500] train loss: 0.466 , accuracy: 84.2%
# [24,   600] train loss: 0.488 , accuracy: 83.3%
# [24,   700] train loss: 0.466 , accuracy: 83.9%
# [24,   800] train loss: 0.460 , accuracy: 84.3%
# [24,   100] validation loss: 1.058 , accuracy: 68.8%
# [24,   200] validation loss: 1.113 , accuracy: 67.8%
# [25,   100] train loss: 0.422 , accuracy: 85.7%
# [25,   200] train loss: 0.433 , accuracy: 84.9%
# [25,   300] train loss: 0.418 , accuracy: 85.8%
# [25,   400] train loss: 0.440 , accuracy: 84.9%
# [25,   500] train loss: 0.454 , accuracy: 84.8%
# [25,   600] train loss: 0.468 , accuracy: 83.7%
# [25,   700] train loss: 0.494 , accuracy: 82.9%
# [25,   800] train loss: 0.469 , accuracy: 83.8%
# [25,   100] validation loss: 1.118 , accuracy: 67.9%
# [25,   200] validation loss: 1.143 , accuracy: 67.6%

# %%
#compare training accuracy of CNN1 and CNN2
plt.figure(figsize=(8,6))
n = len(adamax_lrs[0])
plt.plot(np.arange(0,n),adamax_lrs[0], label = 'Model1')
plt.plot(np.arange(0,n),adamax_lrs_2[0], label = 'Model2')
plt.xlabel('Number of epochs', fontsize=14)
plt.ylabel('Train Accuracy',fontsize=14)
plt.ylim(0,100)
plt.legend()
plt.title('Comparison of Neural network architectures', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Comparison of Neural network architectures')

# %%
#define class for CNN3
class Model3(nn.Module):
    def __init__(self):
        super(Model3, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=3),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.MaxPool2d(2))
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 32, kernel_size=3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
          
        
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU())
        
        self.fc_layers = nn.Sequential(
            nn.Linear(1024,120),
            nn.BatchNorm1d(120),
            #nn.Dropout(0.1),
            nn.Linear(120,84),
            nn.BatchNorm1d(84),
            #nn.Dropout(0.1),
            nn.Linear(84,10)
        )
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)
        out = self.fc_layers(out)
        return out

# %%
#augment images in train set
trainloader_ag,validloader = get_train_valid_loader(batch_size=50,
                           augment=True,
                           data_dir = './data',
                           random_seed=42,
                           valid_size=0.2,
                           shuffle=True,
                           show_sample=False,
                           num_workers=4,
                           pin_memory=False)
dataloaders = {'train': trainloader_ag, 'validation':validloader}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Train model with CNN2 + image augmentation, Adamax optimizer, CLR method scheduling, for 25 epochs
adamax_lrs_2_ag = train_model_lrs(Model2(), 'Adamax', n_epochs=25,lr_max=2e-3, plot_history=True,print_stats=True, path = 'adamax_lrs_2_ag')
# Out:
# [1,   100] train loss: 2.205 , accuracy: 16.7%
# [1,   200] train loss: 2.057 , accuracy: 24.8%
# [1,   300] train loss: 1.962 , accuracy: 28.8%
# [1,   400] train loss: 1.900 , accuracy: 30.4%
# [1,   500] train loss: 1.839 , accuracy: 33.2%
# [1,   600] train loss: 1.763 , accuracy: 35.3%
# [1,   700] train loss: 1.732 , accuracy: 36.0%
# [1,   800] train loss: 1.726 , accuracy: 36.1%
# [1,   100] validation loss: 1.591 , accuracy: 41.1%
# [1,   200] validation loss: 1.630 , accuracy: 40.1%
# [2,   100] train loss: 1.686 , accuracy: 37.8%
# [2,   200] train loss: 1.637 , accuracy: 39.2%
# [2,   300] train loss: 1.656 , accuracy: 39.0%
# [2,   400] train loss: 1.615 , accuracy: 39.9%
# [2,   500] train loss: 1.581 , accuracy: 41.4%
# [2,   600] train loss: 1.571 , accuracy: 42.5%
# [2,   700] train loss: 1.591 , accuracy: 42.0%
# [2,   800] train loss: 1.560 , accuracy: 42.8%
# [2,   100] validation loss: 1.425 , accuracy: 48.6%
# [2,   200] validation loss: 1.430 , accuracy: 47.4%
# [3,   100] train loss: 1.551 , accuracy: 42.7%
# [3,   200] train loss: 1.494 , accuracy: 45.7%
# [3,   300] train loss: 1.482 , accuracy: 45.4%
# [3,   400] train loss: 1.497 , accuracy: 45.8%
# [3,   500] train loss: 1.462 , accuracy: 45.9%
# [3,   600] train loss: 1.475 , accuracy: 46.9%
# [3,   700] train loss: 1.438 , accuracy: 47.6%
# [3,   800] train loss: 1.436 , accuracy: 48.1%
# [3,   100] validation loss: 1.331 , accuracy: 52.2%
# [3,   200] validation loss: 1.292 , accuracy: 53.1%
# [4,   100] train loss: 1.413 , accuracy: 49.2%
# [4,   200] train loss: 1.386 , accuracy: 50.3%
# [4,   300] train loss: 1.385 , accuracy: 50.1%
# [4,   400] train loss: 1.373 , accuracy: 50.1%
# [4,   500] train loss: 1.339 , accuracy: 51.0%
# [4,   600] train loss: 1.381 , accuracy: 51.1%
# [4,   700] train loss: 1.357 , accuracy: 51.0%
# [4,   800] train loss: 1.357 , accuracy: 51.0%
# [4,   100] validation loss: 1.311 , accuracy: 51.6%
# [4,   200] validation loss: 1.299 , accuracy: 52.9%
# [5,   100] train loss: 1.334 , accuracy: 52.0%
# [5,   200] train loss: 1.310 , accuracy: 52.2%
# [5,   300] train loss: 1.296 , accuracy: 53.1%
# [5,   400] train loss: 1.297 , accuracy: 54.2%
# [5,   500] train loss: 1.311 , accuracy: 52.8%
# [5,   600] train loss: 1.274 , accuracy: 54.9%
# [5,   700] train loss: 1.269 , accuracy: 54.4%
# [5,   800] train loss: 1.266 , accuracy: 55.4%
# [5,   100] validation loss: 1.158 , accuracy: 59.3%
# [5,   200] validation loss: 1.140 , accuracy: 59.3%
# [6,   100] train loss: 1.229 , accuracy: 56.0%
# [6,   200] train loss: 1.246 , accuracy: 56.5%
# [6,   300] train loss: 1.238 , accuracy: 55.2%
# [6,   400] train loss: 1.224 , accuracy: 56.7%
# [6,   500] train loss: 1.218 , accuracy: 56.9%
# [6,   600] train loss: 1.202 , accuracy: 57.5%
# [6,   700] train loss: 1.210 , accuracy: 56.7%
# [6,   800] train loss: 1.169 , accuracy: 58.5%
# [6,   100] validation loss: 1.100 , accuracy: 61.5%
# [6,   200] validation loss: 1.130 , accuracy: 60.4%
# [7,   100] train loss: 1.174 , accuracy: 58.7%
# [7,   200] train loss: 1.178 , accuracy: 58.5%
# [7,   300] train loss: 1.153 , accuracy: 59.4%
# [7,   400] train loss: 1.199 , accuracy: 57.7%
# [7,   500] train loss: 1.148 , accuracy: 59.8%
# [7,   600] train loss: 1.161 , accuracy: 58.5%
# [7,   700] train loss: 1.135 , accuracy: 59.1%
# [7,   800] train loss: 1.117 , accuracy: 61.4%
# [7,   100] validation loss: 1.041 , accuracy: 62.9%
# [7,   200] validation loss: 1.047 , accuracy: 63.1%
# [8,   100] train loss: 1.133 , accuracy: 58.5%
# [8,   200] train loss: 1.088 , accuracy: 61.3%
# [8,   300] train loss: 1.137 , accuracy: 59.8%
# [8,   400] train loss: 1.134 , accuracy: 60.0%
# [8,   500] train loss: 1.082 , accuracy: 61.5%
# [8,   600] train loss: 1.094 , accuracy: 60.5%
# [8,   700] train loss: 1.093 , accuracy: 61.6%
# [8,   800] train loss: 1.113 , accuracy: 61.0%
# [8,   100] validation loss: 1.009 , accuracy: 64.1%
# [8,   200] validation loss: 1.006 , accuracy: 65.1%
# [9,   100] train loss: 1.118 , accuracy: 60.8%
# [9,   200] train loss: 1.084 , accuracy: 61.7%
# [9,   300] train loss: 1.084 , accuracy: 61.9%
# [9,   400] train loss: 1.103 , accuracy: 61.4%
# [9,   500] train loss: 1.094 , accuracy: 61.8%
# [9,   600] train loss: 1.074 , accuracy: 61.9%
# [9,   700] train loss: 1.095 , accuracy: 61.6%
# [9,   800] train loss: 1.099 , accuracy: 60.7%
# [9,   100] validation loss: 1.003 , accuracy: 65.0%
# [9,   200] validation loss: 1.000 , accuracy: 64.3%
# [10,   100] train loss: 1.104 , accuracy: 61.3%
# [10,   200] train loss: 1.088 , accuracy: 61.7%
# [10,   300] train loss: 1.082 , accuracy: 61.5%
# [10,   400] train loss: 1.119 , accuracy: 60.7%
# [10,   500] train loss: 1.094 , accuracy: 61.8%
# [10,   600] train loss: 1.095 , accuracy: 62.0%
# [10,   700] train loss: 1.079 , accuracy: 62.4%
# [10,   800] train loss: 1.132 , accuracy: 59.8%
# [10,   100] validation loss: 1.021 , accuracy: 63.7%
# [10,   200] validation loss: 1.000 , accuracy: 65.4%
# [11,   100] train loss: 1.096 , accuracy: 61.2%
# [11,   200] train loss: 1.108 , accuracy: 59.5%
# [11,   300] train loss: 1.112 , accuracy: 61.4%
# [11,   400] train loss: 1.110 , accuracy: 61.0%
# [11,   500] train loss: 1.074 , accuracy: 61.8%
# [11,   600] train loss: 1.109 , accuracy: 60.6%
# [11,   700] train loss: 1.090 , accuracy: 62.6%
# [11,   800] train loss: 1.110 , accuracy: 60.6%
# [11,   100] validation loss: 1.015 , accuracy: 64.4%
# [11,   200] validation loss: 1.008 , accuracy: 64.1%
# [12,   100] train loss: 1.098 , accuracy: 60.4%
# [12,   200] train loss: 1.095 , accuracy: 61.6%
# [12,   300] train loss: 1.095 , accuracy: 60.6%
# [12,   400] train loss: 1.104 , accuracy: 61.3%
# [12,   500] train loss: 1.107 , accuracy: 61.5%
# [12,   600] train loss: 1.081 , accuracy: 62.5%
# [12,   700] train loss: 1.103 , accuracy: 61.1%
# [12,   800] train loss: 1.074 , accuracy: 62.3%
# [12,   100] validation loss: 1.006 , accuracy: 64.8%
# [12,   200] validation loss: 0.999 , accuracy: 64.1%
# [13,   100] train loss: 1.076 , accuracy: 61.6%
# [13,   200] train loss: 1.099 , accuracy: 61.6%
# [13,   300] train loss: 1.073 , accuracy: 62.0%
# [13,   400] train loss: 1.068 , accuracy: 61.9%
# [13,   500] train loss: 1.110 , accuracy: 61.4%
# [13,   600] train loss: 1.070 , accuracy: 62.1%
# [13,   700] train loss: 1.028 , accuracy: 63.9%
# [13,   800] train loss: 1.073 , accuracy: 61.6%
# [13,   100] validation loss: 0.956 , accuracy: 66.3%
# [13,   200] validation loss: 0.963 , accuracy: 66.1%
# [14,   100] train loss: 1.062 , accuracy: 62.0%
# [14,   200] train loss: 1.047 , accuracy: 63.4%
# [14,   300] train loss: 1.021 , accuracy: 64.3%
# [14,   400] train loss: 1.043 , accuracy: 63.4%
# [14,   500] train loss: 1.017 , accuracy: 64.8%
# [14,   600] train loss: 1.030 , accuracy: 64.1%
# [14,   700] train loss: 1.030 , accuracy: 63.1%
# [14,   800] train loss: 1.030 , accuracy: 63.6%
# [14,   100] validation loss: 0.933 , accuracy: 68.0%
# [14,   200] validation loss: 0.923 , accuracy: 67.6%
# [15,   100] train loss: 1.024 , accuracy: 63.9%
# [15,   200] train loss: 1.031 , accuracy: 63.4%
# [15,   300] train loss: 1.005 , accuracy: 65.2%
# [15,   400] train loss: 0.979 , accuracy: 65.9%
# [15,   500] train loss: 1.005 , accuracy: 65.0%
# [15,   600] train loss: 0.973 , accuracy: 66.2%
# [15,   700] train loss: 0.969 , accuracy: 66.5%
# [15,   800] train loss: 0.977 , accuracy: 65.6%
# [15,   100] validation loss: 0.904 , accuracy: 67.9%
# [15,   200] validation loss: 0.911 , accuracy: 67.9%
# [16,   100] train loss: 0.961 , accuracy: 66.6%
# [16,   200] train loss: 0.944 , accuracy: 66.9%
# [16,   300] train loss: 0.997 , accuracy: 65.5%
# [16,   400] train loss: 0.939 , accuracy: 67.6%
# [16,   500] train loss: 0.958 , accuracy: 66.0%
# [16,   600] train loss: 0.955 , accuracy: 66.9%
# [16,   700] train loss: 0.949 , accuracy: 67.0%
# [16,   800] train loss: 0.931 , accuracy: 67.2%
# [16,   100] validation loss: 0.870 , accuracy: 69.7%
# [16,   200] validation loss: 0.877 , accuracy: 69.5%
# [17,   100] train loss: 0.936 , accuracy: 67.0%
# [17,   200] train loss: 0.958 , accuracy: 67.1%
# [17,   300] train loss: 0.977 , accuracy: 65.2%
# [17,   400] train loss: 0.955 , accuracy: 66.2%
# [17,   500] train loss: 0.948 , accuracy: 66.8%
# [17,   600] train loss: 0.932 , accuracy: 67.6%
# [17,   700] train loss: 0.958 , accuracy: 66.8%
# [17,   800] train loss: 0.924 , accuracy: 66.8%
# [17,   100] validation loss: 0.883 , accuracy: 69.3%
# [17,   200] validation loss: 0.877 , accuracy: 69.3%
# [18,   100] train loss: 0.943 , accuracy: 67.2%
# [18,   200] train loss: 0.940 , accuracy: 66.9%
# [18,   300] train loss: 0.953 , accuracy: 66.9%
# [18,   400] train loss: 0.939 , accuracy: 66.5%
# [18,   500] train loss: 0.964 , accuracy: 66.3%
# [18,   600] train loss: 0.985 , accuracy: 65.2%
# [18,   700] train loss: 1.003 , accuracy: 64.5%
# [18,   800] train loss: 0.952 , accuracy: 67.0%
# [18,   100] validation loss: 0.917 , accuracy: 68.2%
# [18,   200] validation loss: 0.874 , accuracy: 69.6%
# [19,   100] train loss: 0.966 , accuracy: 65.3%
# [19,   200] train loss: 0.965 , accuracy: 65.8%
# [19,   300] train loss: 0.972 , accuracy: 66.1%
# [19,   400] train loss: 0.969 , accuracy: 66.3%
# [19,   500] train loss: 1.008 , accuracy: 64.8%
# [19,   600] train loss: 0.984 , accuracy: 66.1%
# [19,   700] train loss: 0.966 , accuracy: 66.4%
# [19,   800] train loss: 0.962 , accuracy: 65.9%
# [19,   100] validation loss: 0.936 , accuracy: 68.1%
# [19,   200] validation loss: 0.937 , accuracy: 67.8%
# [20,   100] train loss: 0.963 , accuracy: 66.4%
# [20,   200] train loss: 0.979 , accuracy: 65.7%
# [20,   300] train loss: 0.976 , accuracy: 65.3%
# [20,   400] train loss: 0.961 , accuracy: 66.4%
# [20,   500] train loss: 0.979 , accuracy: 65.7%
# [20,   600] train loss: 0.997 , accuracy: 65.2%
# [20,   700] train loss: 1.008 , accuracy: 64.8%
# [20,   800] train loss: 1.011 , accuracy: 64.0%
# [20,   100] validation loss: 0.924 , accuracy: 67.8%
# [20,   200] validation loss: 0.908 , accuracy: 67.8%
# [21,   100] train loss: 0.980 , accuracy: 65.8%
# [21,   200] train loss: 0.954 , accuracy: 66.5%
# [21,   300] train loss: 0.982 , accuracy: 65.3%
# [21,   400] train loss: 0.973 , accuracy: 66.8%
# [21,   500] train loss: 0.958 , accuracy: 66.9%
# [21,   600] train loss: 0.964 , accuracy: 66.1%
# [21,   700] train loss: 0.952 , accuracy: 66.3%
# [21,   800] train loss: 0.965 , accuracy: 66.9%
# [21,   100] validation loss: 0.927 , accuracy: 67.7%
# [21,   200] validation loss: 0.930 , accuracy: 68.6%
# [22,   100] train loss: 0.944 , accuracy: 66.7%
# [22,   200] train loss: 0.931 , accuracy: 67.8%
# [22,   300] train loss: 0.917 , accuracy: 68.8%
# [22,   400] train loss: 0.918 , accuracy: 67.6%
# [22,   500] train loss: 0.937 , accuracy: 67.6%
# [22,   600] train loss: 0.937 , accuracy: 67.8%
# [22,   700] train loss: 0.919 , accuracy: 68.7%
# [22,   800] train loss: 0.939 , accuracy: 66.8%
# [22,   100] validation loss: 0.868 , accuracy: 69.8%
# [22,   200] validation loss: 0.867 , accuracy: 69.6%
# [23,   100] train loss: 0.921 , accuracy: 67.8%
# [23,   200] train loss: 0.893 , accuracy: 68.4%
# [23,   300] train loss: 0.918 , accuracy: 67.9%
# [23,   400] train loss: 0.910 , accuracy: 68.0%
# [23,   500] train loss: 0.915 , accuracy: 67.8%
# [23,   600] train loss: 0.910 , accuracy: 68.9%
# [23,   700] train loss: 0.882 , accuracy: 69.3%
# [23,   800] train loss: 0.888 , accuracy: 68.8%
# [23,   100] validation loss: 0.819 , accuracy: 71.4%
# [23,   200] validation loss: 0.845 , accuracy: 71.0%
# [24,   100] train loss: 0.861 , accuracy: 70.0%
# [24,   200] train loss: 0.897 , accuracy: 68.8%
# [24,   300] train loss: 0.862 , accuracy: 70.0%
# [24,   400] train loss: 0.869 , accuracy: 69.9%
# [24,   500] train loss: 0.866 , accuracy: 70.2%
# [24,   600] train loss: 0.857 , accuracy: 70.5%
# [24,   700] train loss: 0.894 , accuracy: 68.8%
# [24,   800] train loss: 0.879 , accuracy: 69.7%
# [24,   100] validation loss: 0.824 , accuracy: 71.3%
# [24,   200] validation loss: 0.810 , accuracy: 71.8%
# [25,   100] train loss: 0.869 , accuracy: 70.1%
# [25,   200] train loss: 0.853 , accuracy: 70.0%
# [25,   300] train loss: 0.886 , accuracy: 69.2%
# [25,   400] train loss: 0.868 , accuracy: 69.6%
# [25,   500] train loss: 0.855 , accuracy: 69.9%
# [25,   600] train loss: 0.859 , accuracy: 69.8%
# [25,   700] train loss: 0.835 , accuracy: 70.0%
# [25,   800] train loss: 0.901 , accuracy: 68.1%
# [25,   100] validation loss: 0.818 , accuracy: 71.9%
# [25,   200] validation loss: 0.825 , accuracy: 70.9%

# %%
#compare generalization gap with and without augmenting images in train set, usinng CNN2
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(14,5))
n = len(adamax_lrs_2[0])
ax1.plot(np.arange(0,n), adamax_lrs_2[0], color = 'orange', label='Train accuracy')
ax1.plot(np.arange(0,n), adamax_lrs_2[1], color = 'r', label='Validation accuracy')
ax1.set_title('Without Image augmentation', fontsize=16)
ax1.set_xlabel('Number of epochs',fontsize=12)
ax1.set_ylabel('Accuracy',fontsize=12)
ax1.legend()
ax2.plot(np.arange(0,n), adamax_lrs_2_ag[0], color = 'orange', label='Train accuracy')
ax2.plot(np.arange(0,n), adamax_lrs_2_ag[1], color = 'r', label='Validation accuracy')
ax2.legend()
ax2.set_title('With Image augmentation', fontsize=16)
ax2.set_xlabel('Number of epochs', fontsize=12)
# Out:
# Text(0.5, 0, 'Number of epochs')

# %%
#Train model with CNN3 + image augmentation + CLR scheduling, for 25 epochs
adamax_lrs_3_ag_25epochs = train_model_lrs(Model3(), 'Adamax', n_epochs=25,lr_max=2e-3, plot_history=True,print_stats=True, path = 'adamax_lrs_3_ag_25epochs')
# Out:
# [1,   100] train loss: 1.972 , accuracy: 28.0%
# [1,   200] train loss: 1.781 , accuracy: 35.5%
# [1,   300] train loss: 1.678 , accuracy: 39.5%
# [1,   400] train loss: 1.637 , accuracy: 39.3%
# [1,   500] train loss: 1.585 , accuracy: 43.3%
# [1,   600] train loss: 1.513 , accuracy: 45.2%
# [1,   700] train loss: 1.502 , accuracy: 45.7%
# [1,   800] train loss: 1.505 , accuracy: 46.0%
# [1,   100] validation loss: 1.362 , accuracy: 51.4%
# [1,   200] validation loss: 1.337 , accuracy: 52.2%
# [2,   100] train loss: 1.420 , accuracy: 49.3%
# [2,   200] train loss: 1.441 , accuracy: 48.2%
# [2,   300] train loss: 1.422 , accuracy: 48.8%
# [2,   400] train loss: 1.410 , accuracy: 49.1%
# [2,   500] train loss: 1.375 , accuracy: 51.4%
# [2,   600] train loss: 1.340 , accuracy: 51.9%
# [2,   700] train loss: 1.350 , accuracy: 51.6%
# [2,   800] train loss: 1.328 , accuracy: 52.3%
# [2,   100] validation loss: 1.200 , accuracy: 57.0%
# [2,   200] validation loss: 1.212 , accuracy: 56.2%
# [3,   100] train loss: 1.321 , accuracy: 53.0%
# [3,   200] train loss: 1.298 , accuracy: 53.2%
# [3,   300] train loss: 1.302 , accuracy: 53.8%
# [3,   400] train loss: 1.313 , accuracy: 53.5%
# [3,   500] train loss: 1.269 , accuracy: 55.1%
# [3,   600] train loss: 1.284 , accuracy: 54.1%
# [3,   700] train loss: 1.260 , accuracy: 55.0%
# [3,   800] train loss: 1.284 , accuracy: 55.1%
# [3,   100] validation loss: 1.106 , accuracy: 59.9%
# [3,   200] validation loss: 1.109 , accuracy: 59.6%
# [4,   100] train loss: 1.245 , accuracy: 55.7%
# [4,   200] train loss: 1.241 , accuracy: 56.4%
# [4,   300] train loss: 1.230 , accuracy: 56.1%
# [4,   400] train loss: 1.231 , accuracy: 56.9%
# [4,   500] train loss: 1.207 , accuracy: 57.2%
# [4,   600] train loss: 1.254 , accuracy: 54.7%
# [4,   700] train loss: 1.215 , accuracy: 56.9%
# [4,   800] train loss: 1.175 , accuracy: 59.1%
# [4,   100] validation loss: 1.061 , accuracy: 62.5%
# [4,   200] validation loss: 1.084 , accuracy: 61.2%
# [5,   100] train loss: 1.190 , accuracy: 57.8%
# [5,   200] train loss: 1.187 , accuracy: 58.2%
# [5,   300] train loss: 1.192 , accuracy: 58.6%
# [5,   400] train loss: 1.171 , accuracy: 59.3%
# [5,   500] train loss: 1.142 , accuracy: 59.7%
# [5,   600] train loss: 1.137 , accuracy: 58.9%
# [5,   700] train loss: 1.127 , accuracy: 60.6%
# [5,   800] train loss: 1.101 , accuracy: 60.8%
# [5,   100] validation loss: 0.984 , accuracy: 65.9%
# [5,   200] validation loss: 0.987 , accuracy: 65.6%
# [6,   100] train loss: 1.106 , accuracy: 61.3%
# [6,   200] train loss: 1.111 , accuracy: 61.1%
# [6,   300] train loss: 1.066 , accuracy: 62.4%
# [6,   400] train loss: 1.092 , accuracy: 61.4%
# [6,   500] train loss: 1.099 , accuracy: 61.7%
# [6,   600] train loss: 1.096 , accuracy: 61.6%
# [6,   700] train loss: 1.073 , accuracy: 62.9%
# [6,   800] train loss: 1.046 , accuracy: 63.8%
# [6,   100] validation loss: 0.940 , accuracy: 66.5%
# [6,   200] validation loss: 0.949 , accuracy: 66.5%
# [7,   100] train loss: 1.044 , accuracy: 63.6%
# [7,   200] train loss: 1.083 , accuracy: 62.0%
# [7,   300] train loss: 1.045 , accuracy: 63.2%
# [7,   400] train loss: 1.023 , accuracy: 64.9%
# [7,   500] train loss: 1.024 , accuracy: 64.1%
# [7,   600] train loss: 1.034 , accuracy: 64.3%
# [7,   700] train loss: 1.012 , accuracy: 64.8%
# [7,   800] train loss: 1.047 , accuracy: 63.3%
# [7,   100] validation loss: 0.898 , accuracy: 68.2%
# [7,   200] validation loss: 0.899 , accuracy: 68.9%
# [8,   100] train loss: 1.010 , accuracy: 65.5%
# [8,   200] train loss: 1.029 , accuracy: 63.0%
# [8,   300] train loss: 1.003 , accuracy: 64.5%
# [8,   400] train loss: 1.012 , accuracy: 64.7%
# [8,   500] train loss: 1.003 , accuracy: 65.4%
# [8,   600] train loss: 0.991 , accuracy: 65.5%
# [8,   700] train loss: 0.977 , accuracy: 65.4%
# [8,   800] train loss: 0.979 , accuracy: 65.2%
# [8,   100] validation loss: 0.858 , accuracy: 70.4%
# [8,   200] validation loss: 0.866 , accuracy: 69.2%
# [9,   100] train loss: 0.963 , accuracy: 66.7%
# [9,   200] train loss: 0.964 , accuracy: 66.4%
# [9,   300] train loss: 0.988 , accuracy: 65.7%
# [9,   400] train loss: 0.975 , accuracy: 66.7%
# [9,   500] train loss: 0.976 , accuracy: 65.5%
# [9,   600] train loss: 0.995 , accuracy: 64.7%
# [9,   700] train loss: 0.980 , accuracy: 65.6%
# [9,   800] train loss: 0.991 , accuracy: 65.1%
# [9,   100] validation loss: 0.869 , accuracy: 69.4%
# [9,   200] validation loss: 0.880 , accuracy: 69.4%
# [10,   100] train loss: 0.966 , accuracy: 66.9%
# [10,   200] train loss: 0.988 , accuracy: 65.0%
# [10,   300] train loss: 0.982 , accuracy: 66.1%
# [10,   400] train loss: 0.994 , accuracy: 65.0%
# [10,   500] train loss: 0.990 , accuracy: 65.1%
# [10,   600] train loss: 0.992 , accuracy: 66.1%
# [10,   700] train loss: 0.992 , accuracy: 65.5%
# [10,   800] train loss: 0.975 , accuracy: 65.9%
# [10,   100] validation loss: 0.898 , accuracy: 68.6%
# [10,   200] validation loss: 0.857 , accuracy: 69.8%
# [11,   100] train loss: 1.003 , accuracy: 65.2%
# [11,   200] train loss: 0.995 , accuracy: 64.8%
# [11,   300] train loss: 1.010 , accuracy: 64.9%
# [11,   400] train loss: 0.998 , accuracy: 64.7%
# [11,   500] train loss: 1.020 , accuracy: 63.7%
# [11,   600] train loss: 1.017 , accuracy: 64.7%
# [11,   700] train loss: 1.000 , accuracy: 65.5%
# [11,   800] train loss: 1.004 , accuracy: 64.8%
# [11,   100] validation loss: 0.908 , accuracy: 69.1%
# [11,   200] validation loss: 0.906 , accuracy: 68.1%
# [12,   100] train loss: 0.996 , accuracy: 64.5%
# [12,   200] train loss: 1.010 , accuracy: 64.3%
# [12,   300] train loss: 0.963 , accuracy: 66.5%
# [12,   400] train loss: 1.015 , accuracy: 64.4%
# [12,   500] train loss: 1.023 , accuracy: 64.9%
# [12,   600] train loss: 0.993 , accuracy: 64.6%
# [12,   700] train loss: 0.984 , accuracy: 65.3%
# [12,   800] train loss: 1.041 , accuracy: 64.4%
# [12,   100] validation loss: 1.025 , accuracy: 63.3%
# [12,   200] validation loss: 0.993 , accuracy: 65.7%
# [13,   100] train loss: 0.976 , accuracy: 65.0%
# [13,   200] train loss: 0.987 , accuracy: 65.5%
# [13,   300] train loss: 1.012 , accuracy: 65.1%
# [13,   400] train loss: 1.014 , accuracy: 64.3%
# [13,   500] train loss: 0.983 , accuracy: 65.0%
# [13,   600] train loss: 1.009 , accuracy: 65.0%
# [13,   700] train loss: 0.973 , accuracy: 65.6%
# [13,   800] train loss: 0.977 , accuracy: 66.3%
# [13,   100] validation loss: 0.917 , accuracy: 68.4%
# [13,   200] validation loss: 0.911 , accuracy: 67.2%
# [14,   100] train loss: 0.959 , accuracy: 66.5%
# [14,   200] train loss: 0.967 , accuracy: 66.2%
# [14,   300] train loss: 0.961 , accuracy: 66.8%
# [14,   400] train loss: 0.961 , accuracy: 66.2%
# [14,   500] train loss: 0.956 , accuracy: 66.7%
# [14,   600] train loss: 0.923 , accuracy: 67.7%
# [14,   700] train loss: 0.961 , accuracy: 66.1%
# [14,   800] train loss: 0.955 , accuracy: 66.1%
# [14,   100] validation loss: 0.883 , accuracy: 69.5%
# [14,   200] validation loss: 0.878 , accuracy: 69.3%
# [15,   100] train loss: 0.931 , accuracy: 67.2%
# [15,   200] train loss: 0.907 , accuracy: 68.2%
# [15,   300] train loss: 0.926 , accuracy: 68.1%
# [15,   400] train loss: 0.911 , accuracy: 67.8%
# [15,   500] train loss: 0.906 , accuracy: 67.6%
# [15,   600] train loss: 0.954 , accuracy: 66.6%
# [15,   700] train loss: 0.901 , accuracy: 68.7%
# [15,   800] train loss: 0.911 , accuracy: 68.7%
# [15,   100] validation loss: 0.799 , accuracy: 72.0%
# [15,   200] validation loss: 0.816 , accuracy: 71.9%
# [16,   100] train loss: 0.886 , accuracy: 69.1%
# [16,   200] train loss: 0.896 , accuracy: 69.4%
# [16,   300] train loss: 0.871 , accuracy: 70.1%
# [16,   400] train loss: 0.913 , accuracy: 67.7%
# [16,   500] train loss: 0.903 , accuracy: 68.4%
# [16,   600] train loss: 0.870 , accuracy: 69.6%
# [16,   700] train loss: 0.893 , accuracy: 68.7%
# [16,   800] train loss: 0.891 , accuracy: 69.3%
# [16,   100] validation loss: 0.790 , accuracy: 72.0%
# [16,   200] validation loss: 0.772 , accuracy: 73.2%
# [17,   100] train loss: 0.894 , accuracy: 68.4%
# [17,   200] train loss: 0.870 , accuracy: 70.3%
# [17,   300] train loss: 0.887 , accuracy: 69.7%
# [17,   400] train loss: 0.874 , accuracy: 69.2%
# [17,   500] train loss: 0.880 , accuracy: 69.6%
# [17,   600] train loss: 0.900 , accuracy: 69.3%
# [17,   700] train loss: 0.855 , accuracy: 70.3%
# [17,   800] train loss: 0.910 , accuracy: 68.9%
# [17,   100] validation loss: 0.790 , accuracy: 72.5%
# [17,   200] validation loss: 0.807 , accuracy: 72.2%
# [18,   100] train loss: 0.870 , accuracy: 69.6%
# [18,   200] train loss: 0.918 , accuracy: 68.5%
# [18,   300] train loss: 0.907 , accuracy: 68.3%
# [18,   400] train loss: 0.886 , accuracy: 68.3%
# [18,   500] train loss: 0.890 , accuracy: 68.8%
# [18,   600] train loss: 0.900 , accuracy: 69.0%
# [18,   700] train loss: 0.884 , accuracy: 68.7%
# [18,   800] train loss: 0.876 , accuracy: 69.8%
# [18,   100] validation loss: 0.820 , accuracy: 71.7%
# [18,   200] validation loss: 0.791 , accuracy: 72.4%
# [19,   100] train loss: 0.884 , accuracy: 69.5%
# [19,   200] train loss: 0.905 , accuracy: 68.9%
# [19,   300] train loss: 0.890 , accuracy: 68.8%
# [19,   400] train loss: 0.927 , accuracy: 67.4%
# [19,   500] train loss: 0.914 , accuracy: 68.5%
# [19,   600] train loss: 0.923 , accuracy: 68.3%
# [19,   700] train loss: 0.916 , accuracy: 67.5%
# [19,   800] train loss: 0.916 , accuracy: 68.2%
# [19,   100] validation loss: 0.808 , accuracy: 72.3%
# [19,   200] validation loss: 0.830 , accuracy: 70.7%
# [20,   100] train loss: 0.907 , accuracy: 68.4%
# [20,   200] train loss: 0.914 , accuracy: 67.9%
# [20,   300] train loss: 0.923 , accuracy: 67.9%
# [20,   400] train loss: 0.947 , accuracy: 66.9%
# [20,   500] train loss: 0.919 , accuracy: 68.3%
# [20,   600] train loss: 0.906 , accuracy: 68.2%
# [20,   700] train loss: 0.925 , accuracy: 67.1%
# [20,   800] train loss: 0.929 , accuracy: 67.7%
# [20,   100] validation loss: 0.813 , accuracy: 72.5%
# [20,   200] validation loss: 0.823 , accuracy: 70.6%
# [21,   100] train loss: 0.919 , accuracy: 68.3%
# [21,   200] train loss: 0.927 , accuracy: 68.1%
# [21,   300] train loss: 0.933 , accuracy: 67.2%
# [21,   400] train loss: 0.906 , accuracy: 67.6%
# [21,   500] train loss: 0.926 , accuracy: 68.1%
# [21,   600] train loss: 0.893 , accuracy: 69.0%
# [21,   700] train loss: 0.928 , accuracy: 67.8%
# [21,   800] train loss: 0.889 , accuracy: 69.4%
# [21,   100] validation loss: 0.818 , accuracy: 71.4%
# [21,   200] validation loss: 0.850 , accuracy: 69.9%
# [22,   100] train loss: 0.888 , accuracy: 68.9%
# [22,   200] train loss: 0.906 , accuracy: 68.8%
# [22,   300] train loss: 0.877 , accuracy: 69.8%
# [22,   400] train loss: 0.880 , accuracy: 70.1%
# [22,   500] train loss: 0.878 , accuracy: 69.0%
# [22,   600] train loss: 0.878 , accuracy: 69.8%
# [22,   700] train loss: 0.910 , accuracy: 68.1%
# [22,   800] train loss: 0.866 , accuracy: 69.2%
# [22,   100] validation loss: 0.779 , accuracy: 72.6%
# [22,   200] validation loss: 0.776 , accuracy: 72.9%
# [23,   100] train loss: 0.854 , accuracy: 70.4%
# [23,   200] train loss: 0.866 , accuracy: 69.9%
# [23,   300] train loss: 0.875 , accuracy: 69.8%
# [23,   400] train loss: 0.844 , accuracy: 70.5%
# [23,   500] train loss: 0.873 , accuracy: 69.4%
# [23,   600] train loss: 0.855 , accuracy: 70.0%
# [23,   700] train loss: 0.826 , accuracy: 70.6%
# [23,   800] train loss: 0.880 , accuracy: 69.5%
# [23,   100] validation loss: 0.756 , accuracy: 73.3%
# [23,   200] validation loss: 0.751 , accuracy: 74.2%
# [24,   100] train loss: 0.849 , accuracy: 70.3%
# [24,   200] train loss: 0.840 , accuracy: 71.0%
# [24,   300] train loss: 0.830 , accuracy: 70.8%
# [24,   400] train loss: 0.833 , accuracy: 71.2%
# [24,   500] train loss: 0.828 , accuracy: 71.3%
# [24,   600] train loss: 0.823 , accuracy: 71.0%
# [24,   700] train loss: 0.836 , accuracy: 71.0%
# [24,   800] train loss: 0.829 , accuracy: 71.7%
# [24,   100] validation loss: 0.739 , accuracy: 74.4%
# [24,   200] validation loss: 0.749 , accuracy: 73.4%
# [25,   100] train loss: 0.809 , accuracy: 72.3%
# [25,   200] train loss: 0.826 , accuracy: 71.3%
# [25,   300] train loss: 0.808 , accuracy: 71.8%
# [25,   400] train loss: 0.840 , accuracy: 71.0%
# [25,   500] train loss: 0.829 , accuracy: 71.2%
# [25,   600] train loss: 0.826 , accuracy: 71.0%
# [25,   700] train loss: 0.836 , accuracy: 70.7%
# [25,   800] train loss: 0.836 , accuracy: 70.8%
# [25,   100] validation loss: 0.740 , accuracy: 74.2%
# [25,   200] validation loss: 0.778 , accuracy: 73.0%

# %%
#Train model with CNN3 + image augmentation + CLR scheduling, for 100 epochs
adamax_lrs_2_BND_ag = train_model_lrs(Model3(), 'Adamax', n_epochs=100,lr_max=2e-3,path='adamax_lrs_2_BND_ag.pth', plot_history=True,print_stats=False)

# %%
#define function to evalute dataset for classification accuracy
def model_eval(testloader,model,weights_path):
    net = model
    net.load_state_dict(torch.load(weights_path)) 
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            accuracy = 100*correct/total

    return accuracy

# %%
#define class for CNN4
class Model4(nn.Module):
    def __init__(self):
        super(Model4, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=3),
            nn.BatchNorm2d(8),
            nn.ReLU())
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(8, 32, kernel_size=3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
          
        
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU())
        
        self.layer4 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
        nn.MaxPool2d(2))
        
        self.layer5 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3),
            nn.BatchNorm2d(256),
            nn.ReLU())
        
        self.fc_layers = nn.Sequential(
            nn.Linear(2304,1024),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.3),
            nn.Linear(1024,256),
            nn.BatchNorm1d(256),
            nn.Dropout(0.3),
            nn.Linear(256,10)
        )
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = out.view(out.size(0), -1)
        out = self.fc_layers(out)
        return out

# %%
#Train model with CNN4 + image augmentation, Adamax optimizer, default learning rate, for 25 epochs
adamax_def_4 = train_model(Model4(), 'Adamax', n_epochs=25, plot_history=True,print_stats=True)
# Out:
# [1,   100] train loss: 1.904 , accuracy: 30.7%
# [1,   200] train loss: 1.646 , accuracy: 39.1%
# [1,   300] train loss: 1.571 , accuracy: 44.4%
# [1,   400] train loss: 1.481 , accuracy: 45.5%
# [1,   500] train loss: 1.391 , accuracy: 49.8%
# [1,   600] train loss: 1.348 , accuracy: 50.8%
# [1,   700] train loss: 1.307 , accuracy: 54.1%
# [1,   800] train loss: 1.303 , accuracy: 52.6%
# [1,   100] validation loss: 1.126 , accuracy: 59.5%
# [1,   200] validation loss: 1.135 , accuracy: 59.5%
# [2,   100] train loss: 1.201 , accuracy: 57.1%
# [2,   200] train loss: 1.209 , accuracy: 57.4%
# [2,   300] train loss: 1.175 , accuracy: 58.2%
# [2,   400] train loss: 1.143 , accuracy: 59.2%
# [2,   500] train loss: 1.128 , accuracy: 60.7%
# [2,   600] train loss: 1.077 , accuracy: 61.7%
# [2,   700] train loss: 1.043 , accuracy: 63.4%
# [2,   800] train loss: 1.055 , accuracy: 63.3%
# [2,   100] validation loss: 0.978 , accuracy: 64.9%
# [2,   200] validation loss: 0.979 , accuracy: 64.9%
# [3,   100] train loss: 1.001 , accuracy: 64.3%
# [3,   200] train loss: 0.995 , accuracy: 64.5%
# [3,   300] train loss: 0.957 , accuracy: 65.5%
# [3,   400] train loss: 0.975 , accuracy: 65.7%
# [3,   500] train loss: 0.951 , accuracy: 67.2%
# [3,   600] train loss: 0.951 , accuracy: 66.4%
# [3,   700] train loss: 0.944 , accuracy: 67.3%
# [3,   800] train loss: 0.896 , accuracy: 68.7%
# [3,   100] validation loss: 0.845 , accuracy: 70.0%
# [3,   200] validation loss: 0.867 , accuracy: 69.3%
# [4,   100] train loss: 0.904 , accuracy: 68.7%
# [4,   200] train loss: 0.889 , accuracy: 68.4%
# [4,   300] train loss: 0.859 , accuracy: 70.1%
# [4,   400] train loss: 0.848 , accuracy: 70.3%
# [4,   500] train loss: 0.844 , accuracy: 70.3%
# [4,   600] train loss: 0.830 , accuracy: 71.6%
# [4,   700] train loss: 0.831 , accuracy: 71.0%
# [4,   800] train loss: 0.857 , accuracy: 70.7%
# [4,   100] validation loss: 0.766 , accuracy: 72.8%
# [4,   200] validation loss: 0.771 , accuracy: 73.2%
# [5,   100] train loss: 0.795 , accuracy: 72.6%
# [5,   200] train loss: 0.823 , accuracy: 70.7%
# [5,   300] train loss: 0.800 , accuracy: 71.9%
# [5,   400] train loss: 0.821 , accuracy: 71.2%
# [5,   500] train loss: 0.773 , accuracy: 73.1%
# [5,   600] train loss: 0.777 , accuracy: 73.0%
# [5,   700] train loss: 0.782 , accuracy: 72.4%
# [5,   800] train loss: 0.768 , accuracy: 72.9%
# [5,   100] validation loss: 0.659 , accuracy: 76.8%
# [5,   200] validation loss: 0.710 , accuracy: 75.7%
# [6,   100] train loss: 0.743 , accuracy: 73.7%
# [6,   200] train loss: 0.739 , accuracy: 74.6%
# [6,   300] train loss: 0.729 , accuracy: 74.5%
# [6,   400] train loss: 0.743 , accuracy: 74.4%
# [6,   500] train loss: 0.747 , accuracy: 73.8%
# [6,   600] train loss: 0.733 , accuracy: 74.9%
# [6,   700] train loss: 0.723 , accuracy: 75.0%
# [6,   800] train loss: 0.757 , accuracy: 74.0%
# [6,   100] validation loss: 0.681 , accuracy: 76.3%
# [6,   200] validation loss: 0.659 , accuracy: 77.6%
# [7,   100] train loss: 0.695 , accuracy: 75.8%
# [7,   200] train loss: 0.691 , accuracy: 76.3%
# [7,   300] train loss: 0.730 , accuracy: 74.8%
# [7,   400] train loss: 0.686 , accuracy: 76.2%
# [7,   500] train loss: 0.682 , accuracy: 76.4%
# [7,   600] train loss: 0.720 , accuracy: 74.8%
# [7,   700] train loss: 0.650 , accuracy: 77.5%
# [7,   800] train loss: 0.676 , accuracy: 76.4%
# [7,   100] validation loss: 0.609 , accuracy: 79.3%
# [7,   200] validation loss: 0.644 , accuracy: 77.2%
# [8,   100] train loss: 0.648 , accuracy: 77.3%
# [8,   200] train loss: 0.632 , accuracy: 78.1%
# [8,   300] train loss: 0.652 , accuracy: 77.4%
# [8,   400] train loss: 0.685 , accuracy: 76.1%
# [8,   500] train loss: 0.642 , accuracy: 78.0%
# [8,   600] train loss: 0.666 , accuracy: 77.0%
# [8,   700] train loss: 0.660 , accuracy: 76.9%
# [8,   800] train loss: 0.649 , accuracy: 78.1%
# [8,   100] validation loss: 0.628 , accuracy: 79.1%
# [8,   200] validation loss: 0.660 , accuracy: 77.9%
# [9,   100] train loss: 0.630 , accuracy: 77.6%
# [9,   200] train loss: 0.606 , accuracy: 78.9%
# [9,   300] train loss: 0.621 , accuracy: 78.2%
# [9,   400] train loss: 0.638 , accuracy: 78.1%
# [9,   500] train loss: 0.609 , accuracy: 79.3%
# [9,   600] train loss: 0.657 , accuracy: 77.3%
# [9,   700] train loss: 0.656 , accuracy: 77.2%
# [9,   800] train loss: 0.623 , accuracy: 78.7%
# [9,   100] validation loss: 0.667 , accuracy: 77.7%
# [9,   200] validation loss: 0.695 , accuracy: 76.6%
# [10,   100] train loss: 0.577 , accuracy: 79.9%
# [10,   200] train loss: 0.598 , accuracy: 79.5%
# [10,   300] train loss: 0.592 , accuracy: 79.7%
# [10,   400] train loss: 0.598 , accuracy: 79.1%
# [10,   500] train loss: 0.623 , accuracy: 78.1%
# [10,   600] train loss: 0.593 , accuracy: 79.4%
# [10,   700] train loss: 0.624 , accuracy: 77.9%
# [10,   800] train loss: 0.576 , accuracy: 80.0%
# [10,   100] validation loss: 0.552 , accuracy: 81.3%
# [10,   200] validation loss: 0.572 , accuracy: 80.0%
# [11,   100] train loss: 0.575 , accuracy: 79.6%
# [11,   200] train loss: 0.566 , accuracy: 80.6%
# [11,   300] train loss: 0.584 , accuracy: 79.1%
# [11,   400] train loss: 0.579 , accuracy: 79.8%
# [11,   500] train loss: 0.571 , accuracy: 80.5%
# [11,   600] train loss: 0.579 , accuracy: 80.3%
# [11,   700] train loss: 0.568 , accuracy: 80.3%
# [11,   800] train loss: 0.577 , accuracy: 79.9%
# [11,   100] validation loss: 0.562 , accuracy: 81.2%
# [11,   200] validation loss: 0.565 , accuracy: 81.0%
# [12,   100] train loss: 0.551 , accuracy: 81.4%
# [12,   200] train loss: 0.567 , accuracy: 80.0%
# [12,   300] train loss: 0.555 , accuracy: 81.1%
# [12,   400] train loss: 0.565 , accuracy: 80.5%
# [12,   500] train loss: 0.575 , accuracy: 80.1%
# [12,   600] train loss: 0.574 , accuracy: 80.1%
# [12,   700] train loss: 0.572 , accuracy: 79.6%
# [12,   800] train loss: 0.545 , accuracy: 81.2%
# [12,   100] validation loss: 0.512 , accuracy: 82.5%
# [12,   200] validation loss: 0.510 , accuracy: 82.7%
# [13,   100] train loss: 0.545 , accuracy: 81.2%
# [13,   200] train loss: 0.508 , accuracy: 82.6%
# [13,   300] train loss: 0.548 , accuracy: 81.3%
# [13,   400] train loss: 0.534 , accuracy: 81.0%
# [13,   500] train loss: 0.536 , accuracy: 81.8%
# [13,   600] train loss: 0.535 , accuracy: 81.7%
# [13,   700] train loss: 0.541 , accuracy: 81.2%
# [13,   800] train loss: 0.547 , accuracy: 80.9%
# [13,   100] validation loss: 0.538 , accuracy: 81.5%
# [13,   200] validation loss: 0.528 , accuracy: 81.8%
# [14,   100] train loss: 0.486 , accuracy: 83.0%
# [14,   200] train loss: 0.519 , accuracy: 81.9%
# [14,   300] train loss: 0.501 , accuracy: 82.8%
# [14,   400] train loss: 0.504 , accuracy: 82.9%
# [14,   500] train loss: 0.540 , accuracy: 81.4%
# [14,   600] train loss: 0.523 , accuracy: 81.9%
# [14,   700] train loss: 0.547 , accuracy: 81.2%
# [14,   800] train loss: 0.506 , accuracy: 82.6%
# [14,   100] validation loss: 0.539 , accuracy: 82.1%
# [14,   200] validation loss: 0.571 , accuracy: 80.7%
# [15,   100] train loss: 0.525 , accuracy: 82.3%
# [15,   200] train loss: 0.503 , accuracy: 82.3%
# [15,   300] train loss: 0.519 , accuracy: 82.0%
# [15,   400] train loss: 0.507 , accuracy: 82.3%
# [15,   500] train loss: 0.472 , accuracy: 83.4%
# [15,   600] train loss: 0.475 , accuracy: 83.8%
# [15,   700] train loss: 0.518 , accuracy: 81.9%
# [15,   800] train loss: 0.492 , accuracy: 82.7%
# [15,   100] validation loss: 0.516 , accuracy: 82.4%
# [15,   200] validation loss: 0.528 , accuracy: 82.0%
# [16,   100] train loss: 0.474 , accuracy: 83.5%
# [16,   200] train loss: 0.473 , accuracy: 83.4%
# [16,   300] train loss: 0.486 , accuracy: 83.7%
# [16,   400] train loss: 0.488 , accuracy: 83.5%
# [16,   500] train loss: 0.479 , accuracy: 83.4%
# [16,   600] train loss: 0.495 , accuracy: 82.9%
# [16,   700] train loss: 0.493 , accuracy: 83.2%
# [16,   800] train loss: 0.500 , accuracy: 82.2%
# [16,   100] validation loss: 0.472 , accuracy: 83.5%
# [16,   200] validation loss: 0.501 , accuracy: 82.6%
# [17,   100] train loss: 0.442 , accuracy: 84.9%
# [17,   200] train loss: 0.463 , accuracy: 83.8%
# [17,   300] train loss: 0.450 , accuracy: 84.5%
# [17,   400] train loss: 0.495 , accuracy: 83.0%
# [17,   500] train loss: 0.474 , accuracy: 83.2%
# [17,   600] train loss: 0.486 , accuracy: 83.2%
# [17,   700] train loss: 0.492 , accuracy: 83.1%
# [17,   800] train loss: 0.471 , accuracy: 83.3%
# [17,   100] validation loss: 0.474 , accuracy: 83.2%
# [17,   200] validation loss: 0.501 , accuracy: 83.1%
# [18,   100] train loss: 0.479 , accuracy: 83.5%
# [18,   200] train loss: 0.445 , accuracy: 84.3%
# [18,   300] train loss: 0.455 , accuracy: 84.7%
# [18,   400] train loss: 0.483 , accuracy: 83.6%
# [18,   500] train loss: 0.459 , accuracy: 84.5%
# [18,   600] train loss: 0.430 , accuracy: 84.7%
# [18,   700] train loss: 0.478 , accuracy: 83.6%
# [18,   800] train loss: 0.447 , accuracy: 84.0%
# [18,   100] validation loss: 0.532 , accuracy: 81.7%
# [18,   200] validation loss: 0.521 , accuracy: 82.5%
# [19,   100] train loss: 0.440 , accuracy: 84.6%
# [19,   200] train loss: 0.455 , accuracy: 84.0%
# [19,   300] train loss: 0.451 , accuracy: 84.1%
# [19,   400] train loss: 0.418 , accuracy: 85.3%
# [19,   500] train loss: 0.446 , accuracy: 84.6%
# [19,   600] train loss: 0.448 , accuracy: 84.2%
# [19,   700] train loss: 0.468 , accuracy: 83.7%
# [19,   800] train loss: 0.449 , accuracy: 85.3%
# [19,   100] validation loss: 0.487 , accuracy: 83.7%
# [19,   200] validation loss: 0.453 , accuracy: 84.3%
# [20,   100] train loss: 0.427 , accuracy: 85.2%
# [20,   200] train loss: 0.451 , accuracy: 83.9%
# [20,   300] train loss: 0.442 , accuracy: 84.7%
# [20,   400] train loss: 0.442 , accuracy: 84.7%
# [20,   500] train loss: 0.417 , accuracy: 85.6%
# [20,   600] train loss: 0.439 , accuracy: 85.1%
# [20,   700] train loss: 0.442 , accuracy: 84.8%
# [20,   800] train loss: 0.446 , accuracy: 84.3%
# [20,   100] validation loss: 0.487 , accuracy: 83.9%
# [20,   200] validation loss: 0.477 , accuracy: 83.8%
# [21,   100] train loss: 0.415 , accuracy: 86.1%
# [21,   200] train loss: 0.432 , accuracy: 85.0%
# [21,   300] train loss: 0.420 , accuracy: 85.3%
# [21,   400] train loss: 0.454 , accuracy: 83.8%
# [21,   500] train loss: 0.421 , accuracy: 85.1%
# [21,   600] train loss: 0.421 , accuracy: 85.2%
# [21,   700] train loss: 0.434 , accuracy: 85.0%
# [21,   800] train loss: 0.414 , accuracy: 85.5%
# [21,   100] validation loss: 0.456 , accuracy: 84.5%
# [21,   200] validation loss: 0.442 , accuracy: 84.8%
# [22,   100] train loss: 0.400 , accuracy: 86.2%
# [22,   200] train loss: 0.419 , accuracy: 85.2%
# [22,   300] train loss: 0.430 , accuracy: 85.0%
# [22,   400] train loss: 0.406 , accuracy: 86.0%
# [22,   500] train loss: 0.411 , accuracy: 85.9%
# [22,   600] train loss: 0.405 , accuracy: 85.9%
# [22,   700] train loss: 0.421 , accuracy: 85.8%
# [22,   800] train loss: 0.419 , accuracy: 85.1%
# [22,   100] validation loss: 0.481 , accuracy: 83.9%
# [22,   200] validation loss: 0.473 , accuracy: 84.1%
# [23,   100] train loss: 0.387 , accuracy: 86.5%
# [23,   200] train loss: 0.410 , accuracy: 85.7%
# [23,   300] train loss: 0.400 , accuracy: 86.3%
# [23,   400] train loss: 0.425 , accuracy: 84.6%
# [23,   500] train loss: 0.422 , accuracy: 85.4%
# [23,   600] train loss: 0.401 , accuracy: 85.8%
# [23,   700] train loss: 0.420 , accuracy: 85.3%
# [23,   800] train loss: 0.420 , accuracy: 85.4%
# [23,   100] validation loss: 0.465 , accuracy: 84.2%
# [23,   200] validation loss: 0.451 , accuracy: 84.9%
# [24,   100] train loss: 0.399 , accuracy: 85.9%
# [24,   200] train loss: 0.401 , accuracy: 85.7%
# [24,   300] train loss: 0.384 , accuracy: 86.1%
# [24,   400] train loss: 0.391 , accuracy: 87.2%
# [24,   500] train loss: 0.402 , accuracy: 86.6%
# [24,   600] train loss: 0.411 , accuracy: 85.8%
# [24,   700] train loss: 0.420 , accuracy: 85.3%
# [24,   800] train loss: 0.409 , accuracy: 85.7%
# [24,   100] validation loss: 0.468 , accuracy: 84.3%
# [24,   200] validation loss: 0.477 , accuracy: 84.1%
# [25,   100] train loss: 0.388 , accuracy: 86.7%
# [25,   200] train loss: 0.379 , accuracy: 87.2%
# [25,   300] train loss: 0.367 , accuracy: 87.1%
# [25,   400] train loss: 0.396 , accuracy: 86.1%
# [25,   500] train loss: 0.396 , accuracy: 86.0%
# [25,   600] train loss: 0.406 , accuracy: 85.9%
# [25,   700] train loss: 0.371 , accuracy: 86.9%
# [25,   800] train loss: 0.411 , accuracy: 86.0%
# [25,   100] validation loss: 0.433 , accuracy: 86.0%
# [25,   200] validation loss: 0.482 , accuracy: 84.7%

# %%
#Train model with CNN4 + image augmentation, Adamax optimizer, CLR method scheduling, for 25 epochs
adamax_lrs_4 = train_model_lrs(Model4(), 'Adamax', n_epochs=25,lr_max=2e-3,path='adamax_lrs_4.pth', plot_history=True,print_stats=True)
# Out:
# [1,   100] train loss: 1.928 , accuracy: 30.9%
# [1,   200] train loss: 1.702 , accuracy: 37.5%
# [1,   300] train loss: 1.582 , accuracy: 42.5%
# [1,   400] train loss: 1.531 , accuracy: 45.1%
# [1,   500] train loss: 1.457 , accuracy: 46.8%
# [1,   600] train loss: 1.429 , accuracy: 49.0%
# [1,   700] train loss: 1.416 , accuracy: 48.5%
# [1,   800] train loss: 1.337 , accuracy: 51.9%
# [1,   100] validation loss: 1.246 , accuracy: 55.0%
# [1,   200] validation loss: 1.222 , accuracy: 55.9%
# [2,   100] train loss: 1.313 , accuracy: 52.3%
# [2,   200] train loss: 1.288 , accuracy: 53.9%
# [2,   300] train loss: 1.263 , accuracy: 55.0%
# [2,   400] train loss: 1.258 , accuracy: 55.4%
# [2,   500] train loss: 1.238 , accuracy: 56.3%
# [2,   600] train loss: 1.208 , accuracy: 57.4%
# [2,   700] train loss: 1.191 , accuracy: 57.4%
# [2,   800] train loss: 1.193 , accuracy: 57.3%
# [2,   100] validation loss: 1.058 , accuracy: 62.2%
# [2,   200] validation loss: 1.077 , accuracy: 62.1%
# [3,   100] train loss: 1.151 , accuracy: 59.2%
# [3,   200] train loss: 1.144 , accuracy: 59.9%
# [3,   300] train loss: 1.094 , accuracy: 61.6%
# [3,   400] train loss: 1.087 , accuracy: 61.6%
# [3,   500] train loss: 1.106 , accuracy: 61.2%
# [3,   600] train loss: 1.068 , accuracy: 62.3%
# [3,   700] train loss: 1.048 , accuracy: 62.7%
# [3,   800] train loss: 1.053 , accuracy: 63.4%
# [3,   100] validation loss: 0.950 , accuracy: 65.7%
# [3,   200] validation loss: 0.989 , accuracy: 64.7%
# [4,   100] train loss: 1.046 , accuracy: 63.2%
# [4,   200] train loss: 0.984 , accuracy: 64.8%
# [4,   300] train loss: 0.989 , accuracy: 66.3%
# [4,   400] train loss: 0.994 , accuracy: 64.2%
# [4,   500] train loss: 0.990 , accuracy: 65.6%
# [4,   600] train loss: 0.965 , accuracy: 66.5%
# [4,   700] train loss: 0.950 , accuracy: 66.6%
# [4,   800] train loss: 0.958 , accuracy: 65.9%
# [4,   100] validation loss: 0.889 , accuracy: 69.3%
# [4,   200] validation loss: 0.907 , accuracy: 67.9%
# [5,   100] train loss: 0.917 , accuracy: 67.0%
# [5,   200] train loss: 0.908 , accuracy: 68.0%
# [5,   300] train loss: 0.915 , accuracy: 68.1%
# [5,   400] train loss: 0.921 , accuracy: 68.2%
# [5,   500] train loss: 0.865 , accuracy: 69.9%
# [5,   600] train loss: 0.852 , accuracy: 70.0%
# [5,   700] train loss: 0.844 , accuracy: 71.0%
# [5,   800] train loss: 0.804 , accuracy: 72.3%
# [5,   100] validation loss: 0.765 , accuracy: 73.4%
# [5,   200] validation loss: 0.740 , accuracy: 73.1%
# [6,   100] train loss: 0.805 , accuracy: 71.9%
# [6,   200] train loss: 0.765 , accuracy: 73.4%
# [6,   300] train loss: 0.791 , accuracy: 72.6%
# [6,   400] train loss: 0.773 , accuracy: 74.3%
# [6,   500] train loss: 0.772 , accuracy: 73.0%
# [6,   600] train loss: 0.771 , accuracy: 73.7%
# [6,   700] train loss: 0.773 , accuracy: 73.3%
# [6,   800] train loss: 0.737 , accuracy: 74.6%
# [6,   100] validation loss: 0.687 , accuracy: 75.8%
# [6,   200] validation loss: 0.654 , accuracy: 77.2%
# [7,   100] train loss: 0.736 , accuracy: 74.0%
# [7,   200] train loss: 0.713 , accuracy: 75.6%
# [7,   300] train loss: 0.710 , accuracy: 75.9%
# [7,   400] train loss: 0.705 , accuracy: 75.6%
# [7,   500] train loss: 0.690 , accuracy: 75.9%
# [7,   600] train loss: 0.671 , accuracy: 76.0%
# [7,   700] train loss: 0.694 , accuracy: 75.9%
# [7,   800] train loss: 0.672 , accuracy: 76.8%
# [7,   100] validation loss: 0.637 , accuracy: 78.0%
# [7,   200] validation loss: 0.622 , accuracy: 78.7%
# [8,   100] train loss: 0.648 , accuracy: 77.7%
# [8,   200] train loss: 0.617 , accuracy: 78.5%
# [8,   300] train loss: 0.638 , accuracy: 77.5%
# [8,   400] train loss: 0.610 , accuracy: 78.2%
# [8,   500] train loss: 0.609 , accuracy: 79.1%
# [8,   600] train loss: 0.631 , accuracy: 77.9%
# [8,   700] train loss: 0.618 , accuracy: 78.5%
# [8,   800] train loss: 0.601 , accuracy: 78.8%
# [8,   100] validation loss: 0.560 , accuracy: 80.7%
# [8,   200] validation loss: 0.561 , accuracy: 80.9%
# [9,   100] train loss: 0.587 , accuracy: 79.8%
# [9,   200] train loss: 0.621 , accuracy: 77.9%
# [9,   300] train loss: 0.607 , accuracy: 78.9%
# [9,   400] train loss: 0.593 , accuracy: 79.4%
# [9,   500] train loss: 0.591 , accuracy: 79.5%
# [9,   600] train loss: 0.604 , accuracy: 79.3%
# [9,   700] train loss: 0.609 , accuracy: 78.8%
# [9,   800] train loss: 0.593 , accuracy: 79.7%
# [9,   100] validation loss: 0.588 , accuracy: 79.6%
# [9,   200] validation loss: 0.614 , accuracy: 78.5%
# [10,   100] train loss: 0.605 , accuracy: 79.8%
# [10,   200] train loss: 0.595 , accuracy: 79.6%
# [10,   300] train loss: 0.597 , accuracy: 79.1%
# [10,   400] train loss: 0.601 , accuracy: 79.5%
# [10,   500] train loss: 0.627 , accuracy: 77.5%
# [10,   600] train loss: 0.624 , accuracy: 78.9%
# [10,   700] train loss: 0.655 , accuracy: 77.2%
# [10,   800] train loss: 0.651 , accuracy: 77.3%
# [10,   100] validation loss: 0.634 , accuracy: 77.9%
# [10,   200] validation loss: 0.625 , accuracy: 78.8%
# [11,   100] train loss: 0.631 , accuracy: 78.9%
# [11,   200] train loss: 0.607 , accuracy: 79.3%
# [11,   300] train loss: 0.606 , accuracy: 78.6%
# [11,   400] train loss: 0.655 , accuracy: 77.1%
# [11,   500] train loss: 0.648 , accuracy: 78.2%
# [11,   600] train loss: 0.642 , accuracy: 77.0%
# [11,   700] train loss: 0.646 , accuracy: 77.4%
# [11,   800] train loss: 0.651 , accuracy: 76.8%
# [11,   100] validation loss: 0.655 , accuracy: 77.7%
# [11,   200] validation loss: 0.674 , accuracy: 77.1%
# [12,   100] train loss: 0.635 , accuracy: 77.8%
# [12,   200] train loss: 0.627 , accuracy: 77.8%
# [12,   300] train loss: 0.654 , accuracy: 77.4%
# [12,   400] train loss: 0.657 , accuracy: 76.3%
# [12,   500] train loss: 0.639 , accuracy: 78.1%
# [12,   600] train loss: 0.680 , accuracy: 76.3%
# [12,   700] train loss: 0.688 , accuracy: 75.6%
# [12,   800] train loss: 0.681 , accuracy: 76.3%
# [12,   100] validation loss: 0.672 , accuracy: 77.1%
# [12,   200] validation loss: 0.699 , accuracy: 76.3%
# [13,   100] train loss: 0.662 , accuracy: 77.1%
# [13,   200] train loss: 0.631 , accuracy: 78.0%
# [13,   300] train loss: 0.648 , accuracy: 78.0%
# [13,   400] train loss: 0.638 , accuracy: 78.2%
# [13,   500] train loss: 0.637 , accuracy: 77.7%
# [13,   600] train loss: 0.637 , accuracy: 77.8%
# [13,   700] train loss: 0.625 , accuracy: 78.5%
# [13,   800] train loss: 0.632 , accuracy: 77.3%
# [13,   100] validation loss: 0.618 , accuracy: 78.4%
# [13,   200] validation loss: 0.632 , accuracy: 77.9%
# [14,   100] train loss: 0.595 , accuracy: 79.6%
# [14,   200] train loss: 0.572 , accuracy: 80.9%
# [14,   300] train loss: 0.580 , accuracy: 80.3%
# [14,   400] train loss: 0.593 , accuracy: 80.1%
# [14,   500] train loss: 0.582 , accuracy: 79.7%
# [14,   600] train loss: 0.569 , accuracy: 80.2%
# [14,   700] train loss: 0.578 , accuracy: 80.1%
# [14,   800] train loss: 0.599 , accuracy: 79.2%
# [14,   100] validation loss: 0.527 , accuracy: 81.9%
# [14,   200] validation loss: 0.542 , accuracy: 81.5%
# [15,   100] train loss: 0.528 , accuracy: 82.0%
# [15,   200] train loss: 0.529 , accuracy: 81.9%
# [15,   300] train loss: 0.529 , accuracy: 81.4%
# [15,   400] train loss: 0.512 , accuracy: 82.1%
# [15,   500] train loss: 0.534 , accuracy: 81.6%
# [15,   600] train loss: 0.522 , accuracy: 82.1%
# [15,   700] train loss: 0.542 , accuracy: 81.7%
# [15,   800] train loss: 0.510 , accuracy: 82.5%
# [15,   100] validation loss: 0.506 , accuracy: 82.5%
# [15,   200] validation loss: 0.510 , accuracy: 81.9%
# [16,   100] train loss: 0.478 , accuracy: 82.9%
# [16,   200] train loss: 0.477 , accuracy: 84.1%
# [16,   300] train loss: 0.472 , accuracy: 83.6%
# [16,   400] train loss: 0.513 , accuracy: 82.5%
# [16,   500] train loss: 0.471 , accuracy: 83.7%
# [16,   600] train loss: 0.454 , accuracy: 84.3%
# [16,   700] train loss: 0.461 , accuracy: 84.5%
# [16,   800] train loss: 0.470 , accuracy: 84.2%
# [16,   100] validation loss: 0.479 , accuracy: 83.8%
# [16,   200] validation loss: 0.471 , accuracy: 84.0%
# [17,   100] train loss: 0.429 , accuracy: 84.8%
# [17,   200] train loss: 0.467 , accuracy: 84.1%
# [17,   300] train loss: 0.452 , accuracy: 84.4%
# [17,   400] train loss: 0.439 , accuracy: 84.9%
# [17,   500] train loss: 0.455 , accuracy: 84.4%
# [17,   600] train loss: 0.451 , accuracy: 84.6%
# [17,   700] train loss: 0.467 , accuracy: 84.2%
# [17,   800] train loss: 0.470 , accuracy: 83.7%
# [17,   100] validation loss: 0.526 , accuracy: 82.4%
# [17,   200] validation loss: 0.499 , accuracy: 83.5%
# [18,   100] train loss: 0.468 , accuracy: 84.1%
# [18,   200] train loss: 0.464 , accuracy: 83.6%
# [18,   300] train loss: 0.463 , accuracy: 83.7%
# [18,   400] train loss: 0.478 , accuracy: 83.4%
# [18,   500] train loss: 0.456 , accuracy: 84.3%
# [18,   600] train loss: 0.482 , accuracy: 83.4%
# [18,   700] train loss: 0.481 , accuracy: 82.9%
# [18,   800] train loss: 0.509 , accuracy: 81.8%
# [18,   100] validation loss: 0.534 , accuracy: 82.2%
# [18,   200] validation loss: 0.523 , accuracy: 82.5%
# [19,   100] train loss: 0.471 , accuracy: 83.9%
# [19,   200] train loss: 0.492 , accuracy: 82.9%
# [19,   300] train loss: 0.512 , accuracy: 82.3%
# [19,   400] train loss: 0.490 , accuracy: 83.3%
# [19,   500] train loss: 0.510 , accuracy: 82.2%
# [19,   600] train loss: 0.488 , accuracy: 83.1%
# [19,   700] train loss: 0.550 , accuracy: 81.1%
# [19,   800] train loss: 0.550 , accuracy: 80.9%
# [19,   100] validation loss: 0.519 , accuracy: 82.2%
# [19,   200] validation loss: 0.544 , accuracy: 81.6%
# [20,   100] train loss: 0.483 , accuracy: 83.2%
# [20,   200] train loss: 0.500 , accuracy: 83.2%
# [20,   300] train loss: 0.528 , accuracy: 82.0%
# [20,   400] train loss: 0.519 , accuracy: 81.7%
# [20,   500] train loss: 0.512 , accuracy: 82.8%
# [20,   600] train loss: 0.523 , accuracy: 81.7%
# [20,   700] train loss: 0.575 , accuracy: 80.2%
# [20,   800] train loss: 0.552 , accuracy: 80.8%
# [20,   100] validation loss: 0.535 , accuracy: 81.5%
# [20,   200] validation loss: 0.559 , accuracy: 81.7%
# [21,   100] train loss: 0.523 , accuracy: 82.0%
# [21,   200] train loss: 0.537 , accuracy: 81.6%
# [21,   300] train loss: 0.534 , accuracy: 81.1%
# [21,   400] train loss: 0.536 , accuracy: 81.5%
# [21,   500] train loss: 0.537 , accuracy: 81.6%
# [21,   600] train loss: 0.515 , accuracy: 82.6%
# [21,   700] train loss: 0.512 , accuracy: 82.8%
# [21,   800] train loss: 0.511 , accuracy: 82.4%
# [21,   100] validation loss: 0.524 , accuracy: 82.5%
# [21,   200] validation loss: 0.520 , accuracy: 82.9%
# [22,   100] train loss: 0.477 , accuracy: 83.1%
# [22,   200] train loss: 0.495 , accuracy: 83.2%
# [22,   300] train loss: 0.471 , accuracy: 83.9%
# [22,   400] train loss: 0.490 , accuracy: 82.8%
# [22,   500] train loss: 0.476 , accuracy: 83.6%
# [22,   600] train loss: 0.482 , accuracy: 83.0%
# [22,   700] train loss: 0.481 , accuracy: 83.5%
# [22,   800] train loss: 0.458 , accuracy: 84.5%
# [22,   100] validation loss: 0.514 , accuracy: 82.2%
# [22,   200] validation loss: 0.513 , accuracy: 83.0%
# [23,   100] train loss: 0.430 , accuracy: 84.6%
# [23,   200] train loss: 0.442 , accuracy: 84.6%
# [23,   300] train loss: 0.433 , accuracy: 84.9%
# [23,   400] train loss: 0.434 , accuracy: 85.4%
# [23,   500] train loss: 0.452 , accuracy: 84.3%
# [23,   600] train loss: 0.429 , accuracy: 85.3%
# [23,   700] train loss: 0.411 , accuracy: 85.4%
# [23,   800] train loss: 0.421 , accuracy: 85.5%
# [23,   100] validation loss: 0.478 , accuracy: 84.0%
# [23,   200] validation loss: 0.444 , accuracy: 85.5%
# [24,   100] train loss: 0.397 , accuracy: 86.5%
# [24,   200] train loss: 0.405 , accuracy: 86.1%
# [24,   300] train loss: 0.389 , accuracy: 86.6%
# [24,   400] train loss: 0.402 , accuracy: 86.0%
# [24,   500] train loss: 0.400 , accuracy: 85.8%
# [24,   600] train loss: 0.392 , accuracy: 87.1%
# [24,   700] train loss: 0.374 , accuracy: 86.9%
# [24,   800] train loss: 0.387 , accuracy: 86.4%
# [24,   100] validation loss: 0.442 , accuracy: 85.0%
# [24,   200] validation loss: 0.437 , accuracy: 85.5%
# [25,   100] train loss: 0.352 , accuracy: 87.8%
# [25,   200] train loss: 0.375 , accuracy: 87.0%
# [25,   300] train loss: 0.358 , accuracy: 88.0%
# [25,   400] train loss: 0.412 , accuracy: 85.6%
# [25,   500] train loss: 0.375 , accuracy: 86.8%
# [25,   600] train loss: 0.374 , accuracy: 87.3%
# [25,   700] train loss: 0.380 , accuracy: 87.1%
# [25,   800] train loss: 0.404 , accuracy: 86.1%
# [25,   100] validation loss: 0.468 , accuracy: 84.1%
# [25,   200] validation loss: 0.476 , accuracy: 84.7%

# %%
plt.figure(figsize=(8,6))
n = len(adamax_lrs_2_ag[0])
plt.plot(np.arange(0,n),adamax_lrs_2_ag[0], label = 'CNN2 - Without Batch Normalization')
plt.plot(np.arange(0,n),adamax_lrs_3_ag_25epochs[0], label = 'CNN3 - After Batch Normalization')
plt.xlabel('Number of epochs', fontsize=14)
plt.ylabel('Train Accuracy',fontsize=14)
plt.ylim(0,100)
plt.legend()
plt.title('Effect of Batch Normalization', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Effect of Batch Normalization')

# %%
##Train model with CNN1 + image augmentation + CLR scheduling, for 25 epochs (for fair comparison of all network architectures)
adamax_lrs_1_ag = train_model_lrs(Model1(), 'Adamax', n_epochs=25,lr_max=2e-3, plot_history=True,print_stats=True, path = 'adamax_lrs_1_ag_25epochs')
# Out:
# [1,   100] train loss: 2.226 , accuracy: 16.6%
# [1,   200] train loss: 2.045 , accuracy: 25.8%
# [1,   300] train loss: 1.978 , accuracy: 29.0%
# [1,   400] train loss: 1.912 , accuracy: 30.7%
# [1,   500] train loss: 1.853 , accuracy: 32.4%
# [1,   600] train loss: 1.831 , accuracy: 32.1%
# [1,   700] train loss: 1.771 , accuracy: 35.1%
# [1,   800] train loss: 1.771 , accuracy: 35.6%
# [1,   100] validation loss: 1.660 , accuracy: 39.8%
# [1,   200] validation loss: 1.685 , accuracy: 38.0%
# [2,   100] train loss: 1.736 , accuracy: 37.0%
# [2,   200] train loss: 1.708 , accuracy: 37.4%
# [2,   300] train loss: 1.697 , accuracy: 37.3%
# [2,   400] train loss: 1.666 , accuracy: 38.1%
# [2,   500] train loss: 1.653 , accuracy: 39.4%
# [2,   600] train loss: 1.660 , accuracy: 40.1%
# [2,   700] train loss: 1.645 , accuracy: 39.9%
# [2,   800] train loss: 1.599 , accuracy: 41.6%
# [2,   100] validation loss: 1.546 , accuracy: 42.3%
# [2,   200] validation loss: 1.541 , accuracy: 43.6%
# [3,   100] train loss: 1.589 , accuracy: 41.9%
# [3,   200] train loss: 1.582 , accuracy: 42.3%
# [3,   300] train loss: 1.566 , accuracy: 42.9%
# [3,   400] train loss: 1.581 , accuracy: 42.4%
# [3,   500] train loss: 1.557 , accuracy: 43.3%
# [3,   600] train loss: 1.553 , accuracy: 43.9%
# [3,   700] train loss: 1.533 , accuracy: 44.8%
# [3,   800] train loss: 1.507 , accuracy: 44.6%
# [3,   100] validation loss: 1.426 , accuracy: 48.9%
# [3,   200] validation loss: 1.401 , accuracy: 49.1%
# [4,   100] train loss: 1.527 , accuracy: 45.0%
# [4,   200] train loss: 1.522 , accuracy: 45.0%
# [4,   300] train loss: 1.489 , accuracy: 45.7%
# [4,   400] train loss: 1.480 , accuracy: 45.1%
# [4,   500] train loss: 1.487 , accuracy: 46.4%
# [4,   600] train loss: 1.474 , accuracy: 47.2%
# [4,   700] train loss: 1.486 , accuracy: 45.6%
# [4,   800] train loss: 1.428 , accuracy: 47.6%
# [4,   100] validation loss: 1.359 , accuracy: 51.3%
# [4,   200] validation loss: 1.341 , accuracy: 52.2%
# [5,   100] train loss: 1.463 , accuracy: 47.5%
# [5,   200] train loss: 1.417 , accuracy: 48.9%
# [5,   300] train loss: 1.420 , accuracy: 49.1%
# [5,   400] train loss: 1.428 , accuracy: 48.2%
# [5,   500] train loss: 1.406 , accuracy: 50.3%
# [5,   600] train loss: 1.433 , accuracy: 48.0%
# [5,   700] train loss: 1.393 , accuracy: 50.6%
# [5,   800] train loss: 1.406 , accuracy: 49.7%
# [5,   100] validation loss: 1.277 , accuracy: 54.2%
# [5,   200] validation loss: 1.283 , accuracy: 54.4%
# [6,   100] train loss: 1.386 , accuracy: 50.0%
# [6,   200] train loss: 1.362 , accuracy: 51.7%
# [6,   300] train loss: 1.369 , accuracy: 50.7%
# [6,   400] train loss: 1.368 , accuracy: 51.6%
# [6,   500] train loss: 1.367 , accuracy: 51.5%
# [6,   600] train loss: 1.365 , accuracy: 51.2%
# [6,   700] train loss: 1.334 , accuracy: 53.0%
# [6,   800] train loss: 1.323 , accuracy: 52.7%
# [6,   100] validation loss: 1.251 , accuracy: 55.7%
# [6,   200] validation loss: 1.220 , accuracy: 57.2%
# [7,   100] train loss: 1.351 , accuracy: 51.4%
# [7,   200] train loss: 1.346 , accuracy: 51.8%
# [7,   300] train loss: 1.319 , accuracy: 53.4%
# [7,   400] train loss: 1.338 , accuracy: 52.5%
# [7,   500] train loss: 1.309 , accuracy: 54.2%
# [7,   600] train loss: 1.302 , accuracy: 53.0%
# [7,   700] train loss: 1.300 , accuracy: 53.6%
# [7,   800] train loss: 1.308 , accuracy: 54.4%
# [7,   100] validation loss: 1.179 , accuracy: 58.0%
# [7,   200] validation loss: 1.206 , accuracy: 57.1%
# [8,   100] train loss: 1.274 , accuracy: 54.6%
# [8,   200] train loss: 1.276 , accuracy: 54.1%
# [8,   300] train loss: 1.310 , accuracy: 53.9%
# [8,   400] train loss: 1.310 , accuracy: 52.8%
# [8,   500] train loss: 1.299 , accuracy: 53.9%
# [8,   600] train loss: 1.293 , accuracy: 54.6%
# [8,   700] train loss: 1.272 , accuracy: 55.8%
# [8,   800] train loss: 1.300 , accuracy: 53.9%
# [8,   100] validation loss: 1.149 , accuracy: 59.6%
# [8,   200] validation loss: 1.190 , accuracy: 58.1%
# [9,   100] train loss: 1.273 , accuracy: 54.6%
# [9,   200] train loss: 1.270 , accuracy: 55.5%
# [9,   300] train loss: 1.317 , accuracy: 53.1%
# [9,   400] train loss: 1.276 , accuracy: 54.7%
# [9,   500] train loss: 1.261 , accuracy: 55.2%
# [9,   600] train loss: 1.278 , accuracy: 54.6%
# [9,   700] train loss: 1.266 , accuracy: 54.8%
# [9,   800] train loss: 1.293 , accuracy: 54.3%
# [9,   100] validation loss: 1.220 , accuracy: 56.8%
# [9,   200] validation loss: 1.165 , accuracy: 59.1%
# [10,   100] train loss: 1.273 , accuracy: 54.9%
# [10,   200] train loss: 1.300 , accuracy: 52.8%
# [10,   300] train loss: 1.274 , accuracy: 54.4%
# [10,   400] train loss: 1.275 , accuracy: 54.9%
# [10,   500] train loss: 1.307 , accuracy: 53.0%
# [10,   600] train loss: 1.250 , accuracy: 56.1%
# [10,   700] train loss: 1.296 , accuracy: 53.3%
# [10,   800] train loss: 1.294 , accuracy: 53.8%
# [10,   100] validation loss: 1.184 , accuracy: 57.8%
# [10,   200] validation loss: 1.165 , accuracy: 58.7%
# [11,   100] train loss: 1.289 , accuracy: 54.0%
# [11,   200] train loss: 1.269 , accuracy: 55.6%
# [11,   300] train loss: 1.291 , accuracy: 54.4%
# [11,   400] train loss: 1.269 , accuracy: 54.5%
# [11,   500] train loss: 1.291 , accuracy: 54.2%
# [11,   600] train loss: 1.309 , accuracy: 54.0%
# [11,   700] train loss: 1.288 , accuracy: 54.3%
# [11,   800] train loss: 1.265 , accuracy: 55.5%
# [11,   100] validation loss: 1.183 , accuracy: 57.8%
# [11,   200] validation loss: 1.158 , accuracy: 59.2%
# [12,   100] train loss: 1.289 , accuracy: 55.2%
# [12,   200] train loss: 1.312 , accuracy: 54.0%
# [12,   300] train loss: 1.293 , accuracy: 53.4%
# [12,   400] train loss: 1.296 , accuracy: 54.2%
# [12,   500] train loss: 1.262 , accuracy: 55.9%
# [12,   600] train loss: 1.312 , accuracy: 53.1%
# [12,   700] train loss: 1.313 , accuracy: 53.5%
# [12,   800] train loss: 1.254 , accuracy: 55.6%
# [12,   100] validation loss: 1.149 , accuracy: 60.0%
# [12,   200] validation loss: 1.153 , accuracy: 58.8%
# [13,   100] train loss: 1.261 , accuracy: 54.4%
# [13,   200] train loss: 1.283 , accuracy: 53.8%
# [13,   300] train loss: 1.291 , accuracy: 54.6%
# [13,   400] train loss: 1.289 , accuracy: 55.4%
# [13,   500] train loss: 1.257 , accuracy: 55.2%
# [13,   600] train loss: 1.272 , accuracy: 55.1%
# [13,   700] train loss: 1.301 , accuracy: 53.8%
# [13,   800] train loss: 1.260 , accuracy: 55.0%
# [13,   100] validation loss: 1.125 , accuracy: 61.2%
# [13,   200] validation loss: 1.162 , accuracy: 59.2%
# [14,   100] train loss: 1.248 , accuracy: 56.2%
# [14,   200] train loss: 1.239 , accuracy: 56.6%
# [14,   300] train loss: 1.245 , accuracy: 55.7%
# [14,   400] train loss: 1.226 , accuracy: 56.2%
# [14,   500] train loss: 1.243 , accuracy: 55.8%
# [14,   600] train loss: 1.214 , accuracy: 56.5%
# [14,   700] train loss: 1.258 , accuracy: 55.5%
# [14,   800] train loss: 1.223 , accuracy: 57.4%
# [14,   100] validation loss: 1.116 , accuracy: 60.0%
# [14,   200] validation loss: 1.114 , accuracy: 61.6%
# [15,   100] train loss: 1.233 , accuracy: 56.3%
# [15,   200] train loss: 1.219 , accuracy: 56.8%
# [15,   300] train loss: 1.253 , accuracy: 55.6%
# [15,   400] train loss: 1.219 , accuracy: 56.6%
# [15,   500] train loss: 1.211 , accuracy: 56.9%
# [15,   600] train loss: 1.195 , accuracy: 57.6%
# [15,   700] train loss: 1.196 , accuracy: 58.7%
# [15,   800] train loss: 1.189 , accuracy: 58.1%
# [15,   100] validation loss: 1.083 , accuracy: 62.2%
# [15,   200] validation loss: 1.082 , accuracy: 62.1%
# [16,   100] train loss: 1.198 , accuracy: 57.5%
# [16,   200] train loss: 1.199 , accuracy: 58.1%
# [16,   300] train loss: 1.220 , accuracy: 57.1%
# [16,   400] train loss: 1.209 , accuracy: 57.5%
# [16,   500] train loss: 1.192 , accuracy: 57.3%
# [16,   600] train loss: 1.175 , accuracy: 58.0%
# [16,   700] train loss: 1.193 , accuracy: 57.6%
# [16,   800] train loss: 1.162 , accuracy: 59.6%
# [16,   100] validation loss: 1.045 , accuracy: 63.4%
# [16,   200] validation loss: 1.083 , accuracy: 62.0%
# [17,   100] train loss: 1.159 , accuracy: 59.3%
# [17,   200] train loss: 1.191 , accuracy: 58.3%
# [17,   300] train loss: 1.195 , accuracy: 57.5%
# [17,   400] train loss: 1.184 , accuracy: 57.6%
# [17,   500] train loss: 1.174 , accuracy: 58.8%
# [17,   600] train loss: 1.215 , accuracy: 57.4%
# [17,   700] train loss: 1.179 , accuracy: 58.8%
# [17,   800] train loss: 1.188 , accuracy: 57.9%
# [17,   100] validation loss: 1.061 , accuracy: 62.9%
# [17,   200] validation loss: 1.087 , accuracy: 61.5%
# [18,   100] train loss: 1.209 , accuracy: 57.9%
# [18,   200] train loss: 1.173 , accuracy: 59.5%
# [18,   300] train loss: 1.201 , accuracy: 57.2%
# [18,   400] train loss: 1.174 , accuracy: 58.6%
# [18,   500] train loss: 1.208 , accuracy: 57.4%
# [18,   600] train loss: 1.199 , accuracy: 58.0%
# [18,   700] train loss: 1.207 , accuracy: 57.6%
# [18,   800] train loss: 1.208 , accuracy: 57.4%
# [18,   100] validation loss: 1.071 , accuracy: 62.1%
# [18,   200] validation loss: 1.091 , accuracy: 61.3%
# [19,   100] train loss: 1.195 , accuracy: 58.1%
# [19,   200] train loss: 1.206 , accuracy: 57.7%
# [19,   300] train loss: 1.197 , accuracy: 57.5%
# [19,   400] train loss: 1.221 , accuracy: 56.7%
# [19,   500] train loss: 1.196 , accuracy: 58.1%
# [19,   600] train loss: 1.221 , accuracy: 56.8%
# [19,   700] train loss: 1.213 , accuracy: 57.8%
# [19,   800] train loss: 1.223 , accuracy: 57.3%
# [19,   100] validation loss: 1.089 , accuracy: 61.8%
# [19,   200] validation loss: 1.091 , accuracy: 61.7%
# [20,   100] train loss: 1.189 , accuracy: 57.6%
# [20,   200] train loss: 1.228 , accuracy: 56.8%
# [20,   300] train loss: 1.194 , accuracy: 58.5%
# [20,   400] train loss: 1.206 , accuracy: 58.2%
# [20,   500] train loss: 1.228 , accuracy: 56.8%
# [20,   600] train loss: 1.231 , accuracy: 56.4%
# [20,   700] train loss: 1.237 , accuracy: 56.0%
# [20,   800] train loss: 1.216 , accuracy: 58.0%
# [20,   100] validation loss: 1.096 , accuracy: 61.4%
# [20,   200] validation loss: 1.098 , accuracy: 61.6%
# [21,   100] train loss: 1.243 , accuracy: 55.9%
# [21,   200] train loss: 1.198 , accuracy: 57.5%
# [21,   300] train loss: 1.204 , accuracy: 58.0%
# [21,   400] train loss: 1.207 , accuracy: 57.9%
# [21,   500] train loss: 1.200 , accuracy: 57.8%
# [21,   600] train loss: 1.193 , accuracy: 58.2%
# [21,   700] train loss: 1.205 , accuracy: 57.7%
# [21,   800] train loss: 1.231 , accuracy: 57.5%
# [21,   100] validation loss: 1.079 , accuracy: 63.1%
# [21,   200] validation loss: 1.078 , accuracy: 61.6%
# [22,   100] train loss: 1.218 , accuracy: 57.4%
# [22,   200] train loss: 1.195 , accuracy: 58.3%
# [22,   300] train loss: 1.177 , accuracy: 58.4%
# [22,   400] train loss: 1.168 , accuracy: 58.9%
# [22,   500] train loss: 1.179 , accuracy: 58.6%
# [22,   600] train loss: 1.198 , accuracy: 58.0%
# [22,   700] train loss: 1.179 , accuracy: 58.6%
# [22,   800] train loss: 1.175 , accuracy: 59.0%
# [22,   100] validation loss: 1.061 , accuracy: 62.5%
# [22,   200] validation loss: 1.059 , accuracy: 62.6%
# [23,   100] train loss: 1.161 , accuracy: 59.2%
# [23,   200] train loss: 1.168 , accuracy: 58.6%
# [23,   300] train loss: 1.185 , accuracy: 57.6%
# [23,   400] train loss: 1.153 , accuracy: 59.8%
# [23,   500] train loss: 1.201 , accuracy: 58.4%
# [23,   600] train loss: 1.171 , accuracy: 58.8%
# [23,   700] train loss: 1.168 , accuracy: 58.9%
# [23,   800] train loss: 1.157 , accuracy: 58.9%
# [23,   100] validation loss: 1.019 , accuracy: 64.0%
# [23,   200] validation loss: 1.039 , accuracy: 63.2%
# [24,   100] train loss: 1.127 , accuracy: 60.6%
# [24,   200] train loss: 1.158 , accuracy: 59.1%
# [24,   300] train loss: 1.142 , accuracy: 59.6%
# [24,   400] train loss: 1.164 , accuracy: 58.6%
# [24,   500] train loss: 1.154 , accuracy: 59.8%
# [24,   600] train loss: 1.131 , accuracy: 60.6%
# [24,   700] train loss: 1.126 , accuracy: 59.8%
# [24,   800] train loss: 1.154 , accuracy: 59.0%
# [24,   100] validation loss: 1.029 , accuracy: 64.0%
# [24,   200] validation loss: 1.018 , accuracy: 64.1%
# [25,   100] train loss: 1.140 , accuracy: 59.7%
# [25,   200] train loss: 1.119 , accuracy: 60.8%
# [25,   300] train loss: 1.147 , accuracy: 60.2%
# [25,   400] train loss: 1.132 , accuracy: 60.9%
# [25,   500] train loss: 1.130 , accuracy: 60.3%
# [25,   600] train loss: 1.159 , accuracy: 58.2%
# [25,   700] train loss: 1.152 , accuracy: 59.1%
# [25,   800] train loss: 1.142 , accuracy: 60.6%
# [25,   100] validation loss: 1.012 , accuracy: 64.0%
# [25,   200] validation loss: 1.033 , accuracy: 63.9%

# %%
#Compare all network architectures by training models with Adamax optimizer + CLR + image augmentation, for 25 epochs 
plt.figure(figsize=(8,6))
n = len(adamax_lrs_1_ag[0])
plt.plot(np.arange(0,n),adamax_lrs_1_ag[0], label = 'CNN1')
plt.plot(np.arange(0,n),adamax_lrs_2_ag[0], label = 'CNN2')
plt.plot(np.arange(0,n),adamax_lrs_3_ag_25epochs[0], label = 'CNN3')
plt.plot(np.arange(0,n),adamax_lrs_4[0], label = 'CNN4')
plt.xlabel('Number of epochs', fontsize=14)
plt.ylabel('Train Accuracy',fontsize=14)
plt.ylim(0,100)
plt.legend()
plt.title('Comparison of Network Architectures', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Comparison of Network Architectures')

# %%
#Train model with CNN4 + image augmentation + Adamax+ CLR scheduling, for 100 epochs
adamax_lrs_4_ag100epochs = train_model_lrs(Model4(), 'Adamax', n_epochs=100,lr_max=2e-3,path='adamax_lrs_4_ag100epochs.pth', plot_history=True,print_stats=False)

# %%
#plot train and validation accuracy curves of final model (for report)
n = len(adamax_lrs_4_ag100epochs[0])
plt.plot(np.arange(0,n),adamax_lrs_4_ag100epochs[0], label = 'Train', color = 'orange')
plt.plot(np.arange(0,n), adamax_lrs_4_ag100epochs[1], label = 'Validation', color = 'r')
plt.ylim(40,100)
plt.ylabel('Accuracy', fontsize = 12)
plt.xlabel('Number of epochs', fontsize=12)
plt.legend(fontsize=14)

# %%
#evaluate model4 on validation set
val_accuracy = model_eval(validloader,Model4(),'adamax_lrs_4_ag100epochs.pth')
print('Accuracy with CNN4 network on validation data is {}'.format(val_accuracy))
# Out:
# Accuracy with CNN4 network on validation data is 83.76

# %%
#evaluate model4 on test set
test_accuracy = model_eval(testloader,Model4(),'adamax_lrs_4_ag100epochs.pth')
print('Accuracy with CNN4 network on test data is {}'.format(test_accuracy))
# Out:
# Accuracy with CNN4 network on test data is 83.1

# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# WARNING: You are using pip version 20.2.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.

# %%
from torchsummary import summary
summary(Model1(), input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             456
#               ReLU-2            [-1, 6, 28, 28]               0
#          MaxPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#               ReLU-5           [-1, 16, 10, 10]               0
#          MaxPool2d-6             [-1, 16, 5, 5]               0
#             Linear-7                  [-1, 120]          48,120
#             Linear-8                   [-1, 84]          10,164
#             Linear-9                   [-1, 10]             850
# ================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.36
# ----------------------------------------------------------------

# %%
summary(Model2(), input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 30, 30]             224
#               ReLU-2            [-1, 8, 30, 30]               0
#          MaxPool2d-3            [-1, 8, 15, 15]               0
#             Conv2d-4           [-1, 32, 13, 13]           2,336
#               ReLU-5           [-1, 32, 13, 13]               0
#          MaxPool2d-6             [-1, 32, 6, 6]               0
#             Conv2d-7             [-1, 64, 4, 4]          18,496
#               ReLU-8             [-1, 64, 4, 4]               0
#             Linear-9                  [-1, 120]         123,000
#            Linear-10                   [-1, 84]          10,164
#            Linear-11                   [-1, 10]             850
# ================================================================
# Total params: 155,070
# Trainable params: 155,070
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.23
# Params size (MB): 0.59
# Estimated Total Size (MB): 0.84
# ----------------------------------------------------------------

# %%
summary(Model3(), input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 30, 30]             224
#        BatchNorm2d-2            [-1, 8, 30, 30]              16
#               ReLU-3            [-1, 8, 30, 30]               0
#          MaxPool2d-4            [-1, 8, 15, 15]               0
#             Conv2d-5           [-1, 32, 13, 13]           2,336
#        BatchNorm2d-6           [-1, 32, 13, 13]              64
#               ReLU-7           [-1, 32, 13, 13]               0
#          MaxPool2d-8             [-1, 32, 6, 6]               0
#             Conv2d-9             [-1, 64, 4, 4]          18,496
#       BatchNorm2d-10             [-1, 64, 4, 4]             128
#              ReLU-11             [-1, 64, 4, 4]               0
#            Linear-12                  [-1, 120]         123,000
#       BatchNorm1d-13                  [-1, 120]             240
#            Linear-14                   [-1, 84]          10,164
#       BatchNorm1d-15                   [-1, 84]             168
#            Linear-16                   [-1, 10]             850
# ================================================================
# Total params: 155,686
# Trainable params: 155,686
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.34
# Params size (MB): 0.59
# Estimated Total Size (MB): 0.94
# ----------------------------------------------------------------

# %%
summary(Model4(), input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 30, 30]             224
#        BatchNorm2d-2            [-1, 8, 30, 30]              16
#               ReLU-3            [-1, 8, 30, 30]               0
#             Conv2d-4           [-1, 32, 28, 28]           2,336
#        BatchNorm2d-5           [-1, 32, 28, 28]              64
#               ReLU-6           [-1, 32, 28, 28]               0
#          MaxPool2d-7           [-1, 32, 14, 14]               0
#             Conv2d-8           [-1, 64, 12, 12]          18,496
#        BatchNorm2d-9           [-1, 64, 12, 12]             128
#              ReLU-10           [-1, 64, 12, 12]               0
#            Conv2d-11          [-1, 128, 10, 10]          73,856
#       BatchNorm2d-12          [-1, 128, 10, 10]             256
#              ReLU-13          [-1, 128, 10, 10]               0
#         MaxPool2d-14            [-1, 128, 5, 5]               0
#            Conv2d-15            [-1, 256, 3, 3]         295,168
#       BatchNorm2d-16            [-1, 256, 3, 3]             512
#              ReLU-17            [-1, 256, 3, 3]               0
#            Linear-18                 [-1, 1024]       2,360,320
#       BatchNorm1d-19                 [-1, 1024]           2,048
#           Dropout-20                 [-1, 1024]               0
#            Linear-21                  [-1, 256]         262,400
#       BatchNorm1d-22                  [-1, 256]             512
#           Dropout-23                  [-1, 256]               0
#            Linear-24                   [-1, 10]           2,570
# ================================================================
# Total params: 3,018,906
# Trainable params: 3,018,906
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.40
# Params size (MB): 11.52
# Estimated Total Size (MB): 12.93
# ----------------------------------------------------------------
